# %%
import glob
import numpy as np
import scipy as sp
import einops as eo
import matplotlib.pyplot as plt
import math
import plotly.graph_objects as go
from scipy.spatial.transform import Rotation
import magpylib as magpy
import os
import pandas as pd
from datetime import timedelta
import sys
from datetime import datetime

M0 = 1480 #mT
shape = [5*25.4/16, 25.4/8] #radius and height
x0 = np.array([0,0,10, 0,0,1])

# %%
def B_dipole(position, rotation, M0, shape):
    R = np.sqrt(np.sum(position**2, axis=1))
    B = (M0 * (shape[0]) ** 2 * shape[1] / (16)) * (
        (
            3
            * position
            / R[:, np.newaxis] ** 5
            * (eo.einsum(position, rotation, "sensor dim,  dim -> sensor"))[
                :, np.newaxis
            ]
        )
        - rotation[np.newaxis, :] / (R[:, np.newaxis] ** 3)
    )
    return B


def getField_dipole(x, positions, M0, shape):
    position = x[:3]
    axis = x[3:]
    return B_dipole(positions - position, axis, M0, shape)


def getField_dipole_fixed(x, positions, M0, shape):
    position = x[:3]
    axis = x[3:]
    return B_dipole(positions - position, axis, M0, shape)


def cost_dipole(x, B, positions, M0, shape):
    diff = getField_dipole(x, positions, M0, shape) - B
    return np.sum((diff) ** 2)


def getField_cylinder(x, positions, M0, shape):
    B=magpy.getB(
        sources="Cylinder",
        position=x[:3],
        orientation=Rotation.align_vectors(x[3:], np.array([0, 0, 1]))[0],
        observers=positions,
        dimension=shape,
        polarization=(0, 0, M0),
    )
    return B

def cost_cylinder(x, B, positions, M0, shape):
    diff = getField_cylinder(x, positions, M0, shape) - B
    return np.sum((diff) ** 2)

def minimize(x0, B, positions, M0, shape, *args):
    #print("Starting mimimization")
    b_args = (B, positions, M0, shape)
    cons = [{"type": "eq", "fun": lambda x: x[3] ** 2 + x[4] ** 2 + x[5] ** 2 - 1}]
    bounds = [(-100, 100), (-100, 100), (0, 100), (-1, 1), (-1, 1), (-1, 1)]
    res = sp.optimize.minimize(
        fun=cost_dipole, x0=x0, args=b_args, tol=1e-100, constraints=cons, bounds=bounds, options={'maxiter':100000}, *args
    ) 
    #print(f"Finished mimimization with shape {b_args[3]} at {res}")
    return res.x 

def circle_radius(x1, y1, x2, y2, x3, y3):
    # Calculate lengths of sides of the triangle formed by the three points
    a = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
    b = math.sqrt((x3 - x2) ** 2 + (y3 - y2) ** 2)
    c = math.sqrt((x3 - x1) ** 2 + (y3 - y1) ** 2)

    # Calculate the semi-perimeter of the triangle
    s = (a + b + c) / 2

    # Calculate the area of the triangle using Heron's formula
    area = math.sqrt(s * (s - a) * (s - b) * (s - c))

    # Calculate the radius of the circle using the formula: radius = (abc) / (4 * area)
    radius = (a * b * c) / (4 * area)
    
    return radius

def comparison_plot(locact, locpred, axis, relative):

    if axis == 'x':
        ax = 0
    elif axis == 'y':
        ax = 1
    else:
        ax = 2

    index = list(range(len(locact[:,ax])))
    act = locact[:, ax]
    pred = locpred[:, ax]

    rel = ''

    if relative==True:
        act = [x - locact[0, ax] for x in locact[:, ax]]
        pred = [x - locpred[0, ax] for x in locpred[:, ax]]
        rel = ' (Relative)'

    # Plotting
    plt.figure(figsize=(8, 6))
    plt.scatter(index, pred, label='Predicted' + rel)
    plt.scatter(index, act, label='Actual' + rel)
    plt.xlabel('Time Passed (s)')
    plt.ylabel(axis + '-component')
    plt.title('Comparison of '+axis+ ' Location' + rel+ ': Predicted vs Actual')
    plt.legend()
    plt.grid(True)
    plt.show()

    return

def comp_plot3D(locact, locpred, xact, yact, axis, relative):

    if axis == 'x':
        ax = 0
    elif axis == 'y':
        ax = 1
    else:
        ax = 2

    index = list(range(len(locact[:,ax])))
    act = locact[:, ax]
    pred = locpred[:, ax]

    rel = ''

    if relative==True:
        act = [x - locact[0, ax] for x in locact[:, ax]]
        pred = [x - locpred[0, ax] for x in locpred[:, ax]]
        rel = ' (Relative)'

    fig = go.Figure(data=[
        go.Scatter3d(x=xact, y=yact, z=pred, name='Predicted' + rel),
        go.Scatter3d(x=xact, y=yact, z=act, name='Actual' + rel)])
    fig.show()

    return

def displacement_plot(actual, predicted):

    dispx = np.array(predicted[:,0]-predicted[:,0][0])
    dispy = np.array(predicted[:,1]-predicted[:,1][0])
    dispz = np.array(predicted[:,2]-predicted[:,2][0])
    disp = np.sqrt(dispx**2+dispy**2+dispz**2)
    actdispx = np.array(actual[:,0]-actual[:,0][0])
    actdispy = np.array(actual[:,1]-actual[:,1][0])
    actdispz = np.array(actual[:,2]-actual[:,2][0])
    actdisp = np.sqrt(actdispx**2+actdispy**2+actdispz**2)

    plt.figure(figsize=(8, 6))
    plt.scatter(list(range(len(disp))), disp, label='Predicted Displacement')
    plt.scatter(list(range(len(actdisp))), actdisp, label='Actual Displacement')
    plt.xlabel('Time Passed (s)')
    plt.ylabel('Displacement (mm)')
    plt.title('Magnet Displacement')
    plt.legend()
    plt.grid(True)
    plt.show()

    return

# Function to convert HHMMSS to seconds
def time_to_seconds(time_str):
    hours = int(time_str[:2])
    minutes = int(time_str[2:4])
    seconds = int(time_str[4:6])
    return hours * 3600 + minutes * 60 + seconds

def time_to_secondsdf(time_value):
    return time_value.hour * 3600 + time_value.minute * 60 + time_value.second + time_value.microsecond / 1e6

# Function to extract the timestamp part from the file path
def extract_timestamp(file_path):
    # Extract the filename from the file path (without the extension)
    filename = os.path.basename(file_path).replace('.npz', '')
    
    # Split the filename into date, time, and millisecond parts
    date_part = filename.split('-')[0]  # Extracting the 'YYYYMMDD' part
    time_part = filename.split('-')[1]  # Extracting the 'HHMMSS' part
    millisecond_part = filename.split('-')[2]  # Extracting the millisecond part
    
    # Combine date, time, and milliseconds into a full timestamp string
    full_datetime_str = f"{date_part} {time_part}.{millisecond_part}"
    
    # Create a datetime object
    full_datetime = datetime.strptime(full_datetime_str, "%Y%m%d %H%M%S.%f")
    
    return full_datetime

def importfitting(folder):

    file_list = sorted(glob.glob(f'{folder}/*.npz'))
    #print(file_list)
    data = np.load(file_list[0])
    pos = data['pos'][0]
    timestamps = []

    locpred = [np.array([0,0,0])]
    anglepred = [np.array([0,0,0])]
    Bstdev = [np.array(pos)]
    for x in range(len(file_list)):
        try:
            data = np.load(file_list[x])
        except:
            display(file_list[x])
        mags = data['mags']
        pos = data['pos'][0]
        B = np.mean(mags, axis=0)
        mags_stdev = np.std(mags, axis=0)
        timestamps.append(extract_timestamp(file_list[x]))

        x_res = minimize(x0, B, pos, M0, shape)
        locpred = np.append(locpred, [x_res[0:3]], axis=0)
        anglepred = np.append(anglepred, [x_res[3:6]], axis=0)
        Bstdev = np.append(Bstdev, [mags_stdev], axis=0)
    locpred = np.delete(locpred, 0, axis=0)
    anglepred = np.delete(anglepred, 0, axis=0)
    Bstdev = np.delete(Bstdev, 0 ,axis=0)

    return pos, mags, locpred, anglepred, Bstdev, timestamps

def importdata(folder):

    file_list = sorted(glob.glob(f'{folder}/*.npz'))
    #print(file_list)
    data = np.load(file_list[0])
    pos = data['pos'][0]
    B = [np.array(pos)]
    timestamps = []

    for x in range(len(file_list)):
        try:
            data = np.load(file_list[x])
        except:
            display(file_list[x])
        mags = data['mags']
        pos = data['pos'][0]
        mags = np.mean(mags, axis=0)
        
        B = np.append(B, [mags], axis=0)
        timestamps.append(extract_timestamp(file_list[x]))  
    B = np.delete(B, 0, axis=0)

    return B, timestamps

def actualangle(xind, yind, xscal, xcon, yscal, ycon, isoff):

    angact = [np.array([0, 0, 0])]
    for y in range(yind):
        for x in range(xind):
            R = Rotation.from_euler('ZYX' ,np.array([0, yscal*y-ycon, xscal*x-xcon]), degrees=True)
            norm = np.array([[0, 0, 1]])
            rotated = R.apply(norm, inverse=False)[0]
            #add = np.array([np.sin(np.deg2rad(2*y-4)), -np.sin(np.deg2rad(2*x-4)), np.cos(np.deg2rad(2*y-4))*np.cos(np.deg2rad(2*x-4))])
            angact = np.append(angact, [rotated], axis=0)
    angact = np.delete(angact, 0, axis=0)
    locact = angact*isoff

    return angact, locact

def sensorplots(B, timestamps,sensor):
    mag = [np.array([0, 0, 0])]
    for x in range(len(B)):
        mag = np.append(mag, [B[x][sensor]], axis=0)
    mag = np.delete(mag, 0, axis=0)

    measuredbx = go.Scatter(x=timestamps, y=mag[:,0], mode='markers')
    layoutbx = go.Layout(title='b_x over time, sensor ' + str(sensor))
    figbx = go.Figure(data=[measuredbx], layout=layoutbx)
    figbx.update_yaxes(scaleanchor='y')
    figbx.update_layout(
        xaxis_title="Time",
        yaxis_title="b_x [mT]"
    )
    figbx.show()

    measuredby = go.Scatter(x=timestamps, y=mag[:,1], mode='markers')
    layoutby = go.Layout(title='b_y over time sensor ' + str(sensor))
    figby = go.Figure(data=[measuredby], layout=layoutby)
    figby.update_yaxes(scaleanchor='y')
    figby.update_layout(
        xaxis_title="Time",
        yaxis_title="b_y [mT]"
    )
    figby.show()

    measuredbz = go.Scatter(x=timestamps, y=mag[:,2], mode='markers')
    layoutbz = go.Layout(title='b_z over time sensor ' + str(sensor))
    figbz = go.Figure(data=[measuredbz], layout=layoutbz)
    figbz.update_yaxes(scaleanchor='y')
    figbz.update_layout(
        xaxis_title="Time",
        yaxis_title="b_z [mT]"
    )
    figbz.show()

# %%
folder = os.path.join('..', './MLX10102024_D52N52_GK4')
B, timestamps = importdata(folder)

# %%
sensorplots(B, timestamps, 6)

# %% [markdown]
# import functions from MagneticSensorTracking
# graph bx, by, bz for all 16 sensors
# try averaging the sensors logs
# try restarting pi to see if time error is from restarts
# fix the mount

# %%
pos, mags, locpred, anglepred, Bstdev, timestamps = importfitting(folder)
np.append(locpred, anglepred, axis=1)
#print(timeelapsed)
print(len(locpred))
# Out:
# c:\Users\Brandon Nguyen\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_slsqp_py.py:434: RuntimeWarning:
#
# Values in x were outside bounds during a minimize step, clipping to bounds
# 5067

# %%
timestamps
# Define the incorrect and correct times
incorrect_time = pd.to_datetime("6:00:00").time()  # Incorrect time (6:01)
correct_time = pd.to_datetime("12:08:00").time()   # Correct time (2:24)

# Calculate the time difference
time_difference = timedelta(hours=correct_time.hour, minutes=correct_time.minute, seconds=correct_time.second) - \
                  timedelta(hours=incorrect_time.hour, minutes=incorrect_time.minute, seconds=incorrect_time.second)

# Apply the time difference to correct the list of incorrect timestamps
corrected_timestamps = [t + time_difference for t in timestamps]
print(timestamps)
corrected_timestamps
# Out:
# [datetime.datetime(2024, 10, 10, 10, 1, 43, 635129), datetime.datetime(2024, 10, 10, 10, 1, 44, 145356), datetime.datetime(2024, 10, 10, 10, 1, 44, 658955), datetime.datetime(2024, 10, 10, 10, 1, 45, 278389), datetime.datetime(2024, 10, 10, 10, 1, 45, 800875), datetime.datetime(2024, 10, 10, 10, 1, 46, 312285), datetime.datetime(2024, 10, 10, 10, 1, 46, 957391), datetime.datetime(2024, 10, 10, 10, 1, 47, 531389), datetime.datetime(2024, 10, 10, 10, 1, 48, 147055), datetime.datetime(2024, 10, 10, 10, 1, 48, 660625), datetime.datetime(2024, 10, 10, 10, 1, 49, 169539), datetime.datetime(2024, 10, 10, 10, 1, 49, 820440), datetime.datetime(2024, 10, 10, 10, 1, 50, 330615), datetime.datetime(2024, 10, 10, 10, 1, 50, 846499), datetime.datetime(2024, 10, 10, 10, 1, 51, 356162), datetime.datetime(2024, 10, 10, 10, 1, 51, 866384), datetime.datetime(2024, 10, 10, 10, 1, 52, 382413), datetime.datetime(2024, 10, 10, 10, 1, 52, 890418), datetime.datetime(2024, 10, 10, 10, 1, 53, 399999), datetime.datetime(2024, 10, 10, 10, 1, 53, 908692), datetime.datetime(2024, 10, 10, 10, 1, 54, 417478), datetime.datetime(2024, 10, 10, 10, 1, 54, 927340), datetime.datetime(2024, 10, 10, 10, 1, 55, 517201), datetime.datetime(2024, 10, 10, 10, 1, 56, 40345), datetime.datetime(2024, 10, 10, 10, 1, 56, 551306), datetime.datetime(2024, 10, 10, 10, 1, 57, 60344), datetime.datetime(2024, 10, 10, 10, 1, 57, 610100), datetime.datetime(2024, 10, 10, 10, 1, 58, 127003), datetime.datetime(2024, 10, 10, 10, 1, 58, 638749), datetime.datetime(2024, 10, 10, 10, 1, 59, 147230), datetime.datetime(2024, 10, 10, 10, 1, 59, 658713), datetime.datetime(2024, 10, 10, 10, 2, 0, 166880), datetime.datetime(2024, 10, 10, 10, 2, 0, 895445), datetime.datetime(2024, 10, 10, 10, 2, 1, 408916), datetime.datetime(2024, 10, 10, 10, 2, 1, 926644), datetime.datetime(2024, 10, 10, 10, 2, 2, 435691), datetime.datetime(2024, 10, 10, 10, 2, 2, 943116), datetime.datetime(2024, 10, 10, 10, 2, 3, 488990), datetime.datetime(2024, 10, 10, 10, 2, 4, 128250), datetime.datetime(2024, 10, 10, 10, 2, 4, 764774), datetime.datetime(2024, 10, 10, 10, 2, 5, 297719), datetime.datetime(2024, 10, 10, 10, 2, 5, 809112), datetime.datetime(2024, 10, 10, 10, 2, 6, 317101), datetime.datetime(2024, 10, 10, 10, 2, 6, 840981), datetime.datetime(2024, 10, 10, 10, 2, 7, 357084), datetime.datetime(2024, 10, 10, 10, 2, 7, 868227), datetime.datetime(2024, 10, 10, 10, 2, 8, 412835), datetime.datetime(2024, 10, 10, 10, 2, 8, 926938), datetime.datetime(2024, 10, 10, 10, 2, 9, 439890), datetime.datetime(2024, 10, 10, 10, 2, 9, 954312), datetime.datetime(2024, 10, 10, 10, 2, 10, 462366), datetime.datetime(2024, 10, 10, 10, 2, 10, 984036), datetime.datetime(2024, 10, 10, 10, 2, 11, 494499), datetime.datetime(2024, 10, 10, 10, 2, 12, 1706), datetime.datetime(2024, 10, 10, 10, 2, 12, 511046), datetime.datetime(2024, 10, 10, 10, 2, 13, 64955), datetime.datetime(2024, 10, 10, 10, 2, 13, 635522), datetime.datetime(2024, 10, 10, 10, 2, 14, 171343), datetime.datetime(2024, 10, 10, 10, 2, 14, 681015), datetime.datetime(2024, 10, 10, 10, 2, 15, 241288), datetime.datetime(2024, 10, 10, 10, 2, 15, 758065), datetime.datetime(2024, 10, 10, 10, 2, 16, 266460), datetime.datetime(2024, 10, 10, 10, 2, 16, 782410), datetime.datetime(2024, 10, 10, 10, 2, 17, 359032), datetime.datetime(2024, 10, 10, 10, 2, 17, 890952), datetime.datetime(2024, 10, 10, 10, 2, 18, 398858), datetime.datetime(2024, 10, 10, 10, 2, 19, 21443), datetime.datetime(2024, 10, 10, 10, 2, 19, 530498), datetime.datetime(2024, 10, 10, 10, 2, 20, 38127), datetime.datetime(2024, 10, 10, 10, 2, 20, 545757), datetime.datetime(2024, 10, 10, 10, 2, 21, 136790), datetime.datetime(2024, 10, 10, 10, 2, 21, 646552), datetime.datetime(2024, 10, 10, 10, 2, 22, 164803), datetime.datetime(2024, 10, 10, 10, 2, 22, 674793), datetime.datetime(2024, 10, 10, 10, 2, 23, 183431), datetime.datetime(2024, 10, 10, 10, 2, 23, 721240), datetime.datetime(2024, 10, 10, 10, 2, 24, 229196), datetime.datetime(202 ...
# [datetime.datetime(2024, 10, 10, 16, 9, 43, 635129),
#  datetime.datetime(2024, 10, 10, 16, 9, 44, 145356),
#  datetime.datetime(2024, 10, 10, 16, 9, 44, 658955),
#  datetime.datetime(2024, 10, 10, 16, 9, 45, 278389),
#  datetime.datetime(2024, 10, 10, 16, 9, 45, 800875),
#  datetime.datetime(2024, 10, 10, 16, 9, 46, 312285),
#  datetime.datetime(2024, 10, 10, 16, 9, 46, 957391),
#  datetime.datetime(2024, 10, 10, 16, 9, 47, 531389),
#  datetime.datetime(2024, 10, 10, 16, 9, 48, 147055),
#  datetime.datetime(2024, 10, 10, 16, 9, 48, 660625),
#  datetime.datetime(2024, 10, 10, 16, 9, 49, 169539),
#  datetime.datetime(2024, 10, 10, 16, 9, 49, 820440),
#  datetime.datetime(2024, 10, 10, 16, 9, 50, 330615),
#  datetime.datetime(2024, 10, 10, 16, 9, 50, 846499),
#  datetime.datetime(2024, 10, 10, 16, 9, 51, 356162),
#  datetime.datetime(2024, 10, 10, 16, 9, 51, 866384),
#  datetime.datetime(2024, 10, 10, 16, 9, 52, 382413),
#  datetime.datetime(2024, 10, 10, 16, 9, 52, 890418),
#  datetime.datetime(2024, 10, 10, 16, 9, 53, 399999),
#  datetime.datetime(2024, 10, 10, 16, 9, 53, 908692),
#  datetime.datetime(2024, 10, 10, 16, 9, 54, 417478),
#  datetime.datetime(2024, 10, 10, 16, 9, 54, 927340),
#  datetime.datetime(2024, 10, 10, 16, 9, 55, 517201),
#  datetime.datetime(2024, 10, 10, 16, 9, 56, 40345),
#  datetime.datetime(2024, 10, 10, 16, 9, 56, 551306),
#  datetime.datetime(2024, 10, 10, 16, 9, 57, 60344),
#  datetime.datetime(2024, 10, 10, 16, 9, 57, 610100),
#  datetime.datetime(2024, 10, 10, 16, 9, 58, 127003),
#  datetime.datetime(2024, 10, 10, 16, 9, 58, 638749),
#  datetime.datetime(2024, 10, 10, 16, 9, 59, 147230),
#  datetime.datetime(2024, 10, 10, 16, 9, 59, 658713),
#  datetime.datetime(2024, 10, 10, 16, 10, 0, 166880),
#  datetime.datetime(2024, 10, 10, 16, 10, 0, 895445),
#  datetime.datetime(2024, 10, 10, 16, 10, 1, 408916),
#  datetime.datetime(2024, 10, 10, 16, 10, 1, 926644),
#  datetime.datetime(2024, 10, 10, 16, 10, 2, 435691),
#  datetime.datetime(2024, 10, 10, 16, 10, 2, 943116),
#  datetime.datetime(2024, 10, 10, 16, 10, 3, 488990),
#  datetime.datetime(2024, 10, 10, 16, 10, 4, 128250),
#  datetime.datetime(2024, 10, 10, 16, 10, 4, 764774),
#  datetime.datetime(2024, 10, 10, 16, 10, 5, 297719),
#  datetime.datetime(2024, 10, 10, 16, 10, 5, 809112),
#  datetime.datetime(2024, 10, 10, 16, 10, 6, 317101),
#  datetime.datetime(2024, 10, 10, 16, 10, 6, 840981),
#  datetime.datetime(2024, 10, 10, 16, 10, 7, 357084),
#  datetime.datetime(2024, 10, 10, 16, 10, 7, 868227),
#  datetime.datetime(2024, 10, 10, 16, 10, 8, 412835),
#  datetime.datetime(2024, 10, 10, 16, 10, 8, 926938),
#  datetime.datetime(2024, 10, 10, 16, 10, 9, 439890),
#  datetime.datetime(2024, 10, 10, 16, 10, 9, 954312),
#  datetime.datetime(2024, 10, 10, 16, 10, 10, 462366),
#  datetime.datetime(2024, 10, 10, 16, 10, 10, 984036),
#  datetime.datetime(2024, 10, 10, 16, 10, 11, 494499),
#  datetime.datetime(2024, 10, 10, 16, 10, 12, 1706),
#  datetime.datetime(2024, 10, 10, 16, 10, 12, 511046),
#  datetime.datetime(2024, 10, 10, 16, 10, 13, 64955),
#  datetime.datetime(2024, 10, 10, 16, 10, 13, 635522),
#  datetime.datetime(2024, 10, 10, 16, 10, 14, 171343),
#  datetime.datetime(2024, 10, 10, 16, 10, 14, 681015),
#  datetime.datetime(2024, 10, 10, 16, 10, 15, 241288),
#  datetime.datetime(2024, 10, 10, 16, 10, 15, 758065),
#  datetime.datetime(2024, 10, 10, 16, 10, 16, 266460),
#  datetime.datetime(2024, 10, 10, 16, 10, 16, 782410),
#  datetime.datetime(2024, 10, 10, 16, 10, 17, 359032),
#  datetime.datetime(2024, 10, 10, 16, 10, 17, 890952),
#  datetime.datetime(2024, 10, 10, 16, 10, 18, 398858),
#  datetime.datetime(2024, 10, 10, 16, 10, 19, 21443),
#  datetime.datetime(2024, 10, 10, 16, 10, 19, 530498),
#  datetime.datetime(2024, 10, 10, 16, 10, 20, 38127),
#  datetime.datetime(2024, 10, 10, 16, 10, 20, 545757),
#  datetime.datetime(2024, 10, 10, 16, 10, 21, 136790),
#  datetime.datetime(2024, 10, 10, 16, 10, 21, 646552),
#  datetime.datetime(2024, 10, 10, 16, 10, 22, 164803),
#  datetime.datetime(2024, 10, 10, 16, 10, 22, 674793),
#  datetime.datetime(2024, 10, 10, 16, 10, 23, 183431),
#  datetime.datetime(2024, 10, 10, 16, 10, 23, 721240),
#  datetime.datetime(2024, 10, 10, 16, 10, 24, 229196),
#  datetime.datetime(2024, 10, 10, 16, 10, 24, 738100),
#  datetime.datetime(2024, 10, 10, 16, 10, 25, 249019),
#  datetime.datetime(2024, 10, 10, 16, 10, 25, 758189),
#  datetime.datetime(2024, 10, 10, 16, 10, 26, 309427),
#  datetime.datetime(2024, 10, 10, 16, 10, 26, 834244),
#  datetime.datetime(2024, 10, 10, 16, 10, 27, 421628),
#  datetime.datetime(2024, 10, 10, 16, 10, 27, 963037),
#  datetime.datetime(2024, 10, 10, 16, 10, 28, 479819),
#  datetime.datetime(2024, 10, 10, 16, 10, 28, 988872),
#  datetime.datetime(2024, 10, 10, 16, 10, 29, 526965),
#  datetime.datetime(2024, 10, 10, 16, 10, 30, 84633),
#  datetime.datetime(2024, 10, 10, 16, 10, 30, 673783),
#  datetime.datetime(2024, 10, 10, 16, 10, 31, 222124),
#  datetime.datetime(2024, 10, 10, 16, 10, 31, 761692),
#  datetime.datetime(2024, 10, 10, 16, 10, 32, 273179),
#  datetime.datetime(2024, 10, 10, 16, 10, 32, 833143),
#  datetime.datetime(2024, 10, 10, 16, 10, 33, 402104),
#  datetime.datetime(2024, 10, 10, 16, 10, 33, 945304),
#  datetime.datetime(2024, 10, 10, 16, 10, 34, 455464),
#  datetime.datetime(2024, 10, 10, 16, 10, 34, 968354),
#  datetime.datetime(2024, 10, 10, 16, 10, 35, 562130),
#  datetime.datetime(2024, 10, 10, 16, 10, 36, 71986),
#  datetime.datetime(2024, 10, 10, 16, 10, 36, 615561),
#  datetime.datetime(2024, 10, 10, 16, 10, 37, 130694),
#  datetime.datetime(2024, 10, 10, 16, 10, 37, 641208),
#  datetime.datetime(2024, 10, 10, 16, 10, 38, 149849),
#  datetime.datetime(2024, 10, 10, 16, 10, 38, 706406),
#  datetime.datetime(2024, 10, 10, 16, 10, 39, 216546),
#  datetime.datetime(2024, 10, 10, 16, 10, 39, 726936),
#  datetime.datetime(2024, 10, 10, 16, 10, 40, 242553),
#  datetime.datetime(2024, 10, 10, 16, 10, 40, 749683),
#  datetime.datetime(2024, 10, 10, 16, 10, 41, 257438),
#  datetime.datetime(2024, 10, 10, 16, 10, 41, 765328),
#  datetime.datetime(2024, 10, 10, 16, 10, 42, 274993),
#  datetime.datetime(2024, 10, 10, 16, 10, 42, 792027),
#  datetime.datetime(2024, 10, 10, 16, 10, 43, 301944),
#  datetime.datetime(2024, 10, 10, 16, 10, 43, 811996),
#  datetime.datetime(2024, 10, 10, 16, 10, 44, 322874),
#  datetime.datetime(2024, 10, 10, 16, 10, 44, 877267),
#  datetime.datetime(2024, 10, 10, 16, 10, 45, 405483),
#  datetime.datetime(2024, 10, 10, 16, 10, 45, 916232),
#  datetime.datetime(2024, 10, 10, 16, 10, 46, 428479),
#  datetime.datetime(2024, 10, 10, 16, 10, 46, 941729),
#  datetime.datetime(2024, 10, 10, 16, 10, 47, 470227),
#  datetime.datetime(2024, 10, 10, 16, 10, 48, 82425),
#  datetime.datetime(2024, 10, 10, 16, 10, 48, 598218),
#  datetime.datetime(2024, 10, 10, 16, 10, 49, 105475),
#  datetime.datetime(2024, 10, 10, 16, 10, 49, 615969),
#  datetime.datetime(2024, 10, 10, 16, 10, 50, 125544),
#  datetime.datetime(2024, 10, 10, 16, 10, 50, 634117),
#  datetime.datetime(2024, 10, 10, 16, 10, 51, 163712),
#  datetime.datetime(2024, 10, 10, 16, 10, 51, 672881),
#  datetime.datetime(2024, 10, 10, 16, 10, 52, 245243),
#  datetime.datetime(2024, 10, 10, 16, 10, 52, 754471),
#  datetime.datetime(2024, 10, 10, 16, 10, 53, 262332),
#  datetime.datetime(2024, 10, 10, 16, 10, 53, 774114),
#  datetime.datetime(2024, 10, 10, 16, 10, 54, 285244),
#  datetime.datetime(2024, 10, 10, 16, 10, 54, 793933),
#  datetime.datetime(2024, 10, 10, 16, 10, 55, 301609),
#  datetime.datetime(2024, 10, 10, 16, 10, 55, 811427),
#  datetime.datetime(2024, 10, 10, 16, 10, 56, 467564),
#  datetime.datetime(2024, 10, 10, 16, 10, 56, 996830),
#  datetime.datetime(2024, 10, 10, 16, 10, 57, 554678),
#  datetime.datetime(2024, 10, 10, 16, 10, 58, 66188),
#  datetime.datetime(2024, 10, 10, 16, 10, 58, 575842),
#  datetime.datetime(2024, 10, 10, 16, 10, 59, 148541),
#  datetime.datetime(2024, 10, 10, 16, 10, 59, 655914),
#  datetime.datetime(2024, 10, 10, 16, 11, 0, 167615),
#  datetime.datetime(2024, 10, 10, 16, 11, 0, 677422),
#  datetime.datetime(2024, 10, 10, 16, 11, 1, 188631),
#  datetime.datetime(2024, 10, 10, 16, 11, 1, 696688),
#  datetime.datetime(2024, 10, 10, 16, 11, 2, 223067),
#  datetime.datetime(2024, 10, 10, 16, 11, 2, 732421),
#  datetime.datetime(2024, 10, 10, 16, 11, 3, 240502),
#  datetime.datetime(2024, 10, 10, 16, 11, 3, 794852),
#  datetime.datetime(2024, 10, 10, 16, 11, 4, 393188),
#  datetime.datetime(2024, 10, 10, 16, 11, 4, 964998),
#  datetime.datetime(2024, 10, 10, 16, 11, 5, 480764),
#  datetime.datetime(2024, 10, 10, 16, 11, 6, 58576),
#  datetime.datetime(2024, 10, 10, 16, 11, 6, 575788),
#  datetime.datetime(2024, 10, 10, 16, 11, 7, 83934),
#  datetime.datetime(2024, 10, 10, 16, 11, 7, 591948),
#  datetime.datetime(2024, 10, 10, 16, 11, 8, 100435),
#  datetime.datetime(2024, 10, 10, 16, 11, 8, 655502),
#  datetime.datetime(2024, 10, 10, 16, 11, 9, 210444),
#  datetime.datetime(2024, 10, 10, 16, 11, 9, 773612),
#  datetime.datetime(2024, 10, 10, 16, 11, 10, 338121),
#  datetime.datetime(2024, 10, 10, 16, 11, 10, 846928),
#  datetime.datetime(2024, 10, 10, 16, 11, 11, 355086),
#  datetime.datetime(2024, 10, 10, 16, 11, 11, 866024),
#  datetime.datetime(2024, 10, 10, 16, 11, 12, 374615),
#  datetime.datetime(2024, 10, 10, 16, 11, 12, 882318),
#  datetime.datetime(2024, 10, 10, 16, 11, 13, 392318),
#  datetime.datetime(2024, 10, 10, 16, 11, 13, 900402),
#  datetime.datetime(2024, 10, 10, 16, 11, 14, 449161),
#  datetime.datetime(2024, 10, 10, 16, 11, 14, 958101),
#  datetime.datetime(2024, 10, 10, 16, 11, 15, 540717),
#  datetime.datetime(2024, 10, 10, 16, 11, 16, 52509),
#  datetime.datetime(2024, 10, 10, 16, 11, 16, 564504),
#  datetime.datetime(2024, 10, 10, 16, 11, 17, 140162),
#  datetime.datetime(2024, 10, 10, 16, 11, 17, 733084),
#  datetime.datetime(2024, 10, 10, 16, 11, 18, 242276),
#  datetime.datetime(2024, 10, 10, 16, 11, 18, 750593),
#  datetime.datetime(2024, 10, 10, 16, 11, 19, 259476),
#  datetime.datetime(2024, 10, 10, 16, 11, 19, 769746),
#  datetime.datetime(2024, 10, 10, 16, 11, 20, 309292),
#  datetime.datetime(2024, 10, 10, 16, 11, 20, 834436),
#  datetime.datetime(2024, 10, 10, 16, 11, 21, 341805),
#  datetime.datetime(2024, 10, 10, 16, 11, 21, 857822),
#  datetime.datetime(2024, 10, 10, 16, 11, 22, 366267),
#  datetime.datetime(2024, 10, 10, 16, 11, 22, 922796),
#  datetime.datetime(2024, 10, 10, 16, 11, 23, 457377),
#  datetime.datetime(2024, 10, 10, 16, 11, 23, 973096),
#  datetime.datetime(2024, 10, 10, 16, 11, 24, 483694),
#  datetime.datetime(2024, 10, 10, 16, 11, 24, 991787),
#  datetime.datetime(2024, 10, 10, 16, 11, 25, 500649),
#  datetime.datetime(2024, 10, 10, 16, 11, 26, 11019),
#  datetime.datetime(2024, 10, 10, 16, 11, 26, 561082),
#  datetime.datetime(2024, 10, 10, 16, 11, 27, 72631),
#  datetime.datetime(2024, 10, 10, 16, 11, 27, 581797),
#  datetime.datetime(2024, 10, 10, 16, 11, 28, 114541),
#  datetime.datetime(2024, 10, 10, 16, 11, 28, 675775),
#  datetime.datetime(2024, 10, 10, 16, 11, 29, 216057),
#  datetime.datetime(2024, 10, 10, 16, 11, 29, 724643),
#  datetime.datetime(2024, 10, 10, 16, 11, 30, 278276),
#  datetime.datetime(2024, 10, 10, 16, 11, 30, 787341),
#  datetime.datetime(2024, 10, 10, 16, 11, 31, 295449),
#  datetime.datetime(2024, 10, 10, 16, 11, 31, 900352),
#  datetime.datetime(2024, 10, 10, 16, 11, 32, 409186),
#  datetime.datetime(2024, 10, 10, 16, 11, 32, 918661),
#  datetime.datetime(2024, 10, 10, 16, 11, 33, 427433),
#  datetime.datetime(2024, 10, 10, 16, 11, 33, 936532),
#  datetime.datetime(2024, 10, 10, 16, 11, 34, 447329),
#  datetime.datetime(2024, 10, 10, 16, 11, 35, 57708),
#  datetime.datetime(2024, 10, 10, 16, 11, 35, 565649),
#  datetime.datetime(2024, 10, 10, 16, 11, 36, 76060),
#  datetime.datetime(2024, 10, 10, 16, 11, 36, 585498),
#  datetime.datetime(2024, 10, 10, 16, 11, 37, 93111),
#  datetime.datetime(2024, 10, 10, 16, 11, 37, 600566),
#  datetime.datetime(2024, 10, 10, 16, 11, 38, 108702),
#  datetime.datetime(2024, 10, 10, 16, 11, 38, 617608),
#  datetime.datetime(2024, 10, 10, 16, 11, 39, 125938),
#  datetime.datetime(2024, 10, 10, 16, 11, 39, 634078),
#  datetime.datetime(2024, 10, 10, 16, 11, 40, 142135),
#  datetime.datetime(2024, 10, 10, 16, 11, 40, 651674),
#  datetime.datetime(2024, 10, 10, 16, 11, 41, 231920),
#  datetime.datetime(2024, 10, 10, 16, 11, 41, 773293),
#  datetime.datetime(2024, 10, 10, 16, 11, 42, 326756),
#  datetime.datetime(2024, 10, 10, 16, 11, 42, 836366),
#  datetime.datetime(2024, 10, 10, 16, 11, 43, 345021),
#  datetime.datetime(2024, 10, 10, 16, 11, 43, 853758),
#  datetime.datetime(2024, 10, 10, 16, 11, 44, 362182),
#  datetime.datetime(2024, 10, 10, 16, 11, 44, 870084),
#  datetime.datetime(2024, 10, 10, 16, 11, 45, 377582),
#  datetime.datetime(2024, 10, 10, 16, 11, 45, 885132),
#  datetime.datetime(2024, 10, 10, 16, 11, 46, 393093),
#  datetime.datetime(2024, 10, 10, 16, 11, 46, 902205),
#  datetime.datetime(2024, 10, 10, 16, 11, 47, 411769),
#  datetime.datetime(2024, 10, 10, 16, 11, 47, 920055),
#  datetime.datetime(2024, 10, 10, 16, 11, 48, 428375),
#  datetime.datetime(2024, 10, 10, 16, 11, 48, 944051),
#  datetime.datetime(2024, 10, 10, 16, 11, 49, 458241),
#  datetime.datetime(2024, 10, 10, 16, 11, 49, 987986),
#  datetime.datetime(2024, 10, 10, 16, 11, 50, 496115),
#  datetime.datetime(2024, 10, 10, 16, 11, 51, 14857),
#  datetime.datetime(2024, 10, 10, 16, 11, 51, 528059),
#  datetime.datetime(2024, 10, 10, 16, 11, 52, 61755),
#  datetime.datetime(2024, 10, 10, 16, 11, 52, 574222),
#  datetime.datetime(2024, 10, 10, 16, 11, 53, 145363),
#  datetime.datetime(2024, 10, 10, 16, 11, 53, 655716),
#  datetime.datetime(2024, 10, 10, 16, 11, 54, 162967),
#  datetime.datetime(2024, 10, 10, 16, 11, 54, 675681),
#  datetime.datetime(2024, 10, 10, 16, 11, 55, 185034),
#  datetime.datetime(2024, 10, 10, 16, 11, 55, 694497),
#  datetime.datetime(2024, 10, 10, 16, 11, 56, 270016),
#  datetime.datetime(2024, 10, 10, 16, 11, 56, 784769),
#  datetime.datetime(2024, 10, 10, 16, 11, 57, 301011),
#  datetime.datetime(2024, 10, 10, 16, 11, 57, 849806),
#  datetime.datetime(2024, 10, 10, 16, 11, 58, 357728),
#  datetime.datetime(2024, 10, 10, 16, 11, 58, 865372),
#  datetime.datetime(2024, 10, 10, 16, 11, 59, 450433),
#  datetime.datetime(2024, 10, 10, 16, 11, 59, 959275),
#  datetime.datetime(2024, 10, 10, 16, 12, 0, 468380),
#  datetime.datetime(2024, 10, 10, 16, 12, 0, 980949),
#  datetime.datetime(2024, 10, 10, 16, 12, 1, 490124),
#  datetime.datetime(2024, 10, 10, 16, 12, 2, 536),
#  datetime.datetime(2024, 10, 10, 16, 12, 2, 539374),
#  datetime.datetime(2024, 10, 10, 16, 12, 3, 64702),
#  datetime.datetime(2024, 10, 10, 16, 12, 3, 586269),
#  datetime.datetime(2024, 10, 10, 16, 12, 4, 118664),
#  datetime.datetime(2024, 10, 10, 16, 12, 4, 676454),
#  datetime.datetime(2024, 10, 10, 16, 12, 5, 185079),
#  datetime.datetime(2024, 10, 10, 16, 12, 5, 739059),
#  datetime.datetime(2024, 10, 10, 16, 12, 6, 255375),
#  datetime.datetime(2024, 10, 10, 16, 12, 6, 767756),
#  datetime.datetime(2024, 10, 10, 16, 12, 7, 291840),
#  datetime.datetime(2024, 10, 10, 16, 12, 7, 871752),
#  datetime.datetime(2024, 10, 10, 16, 12, 8, 420805),
#  datetime.datetime(2024, 10, 10, 16, 12, 9, 9188),
#  datetime.datetime(2024, 10, 10, 16, 12, 9, 516136),
#  datetime.datetime(2024, 10, 10, 16, 12, 10, 23865),
#  datetime.datetime(2024, 10, 10, 16, 12, 10, 531474),
#  datetime.datetime(2024, 10, 10, 16, 12, 11, 39868),
#  datetime.datetime(2024, 10, 10, 16, 12, 11, 581303),
#  datetime.datetime(2024, 10, 10, 16, 12, 12, 130597),
#  datetime.datetime(2024, 10, 10, 16, 12, 12, 664901),
#  datetime.datetime(2024, 10, 10, 16, 12, 13, 174983),
#  datetime.datetime(2024, 10, 10, 16, 12, 13, 682698),
#  datetime.datetime(2024, 10, 10, 16, 12, 14, 216696),
#  datetime.datetime(2024, 10, 10, 16, 12, 14, 796926),
#  datetime.datetime(2024, 10, 10, 16, 12, 15, 333485),
#  datetime.datetime(2024, 10, 10, 16, 12, 15, 840690),
#  datetime.datetime(2024, 10, 10, 16, 12, 16, 349054),
#  datetime.datetime(2024, 10, 10, 16, 12, 16, 861232),
#  datetime.datetime(2024, 10, 10, 16, 12, 17, 372555),
#  datetime.datetime(2024, 10, 10, 16, 12, 17, 927796),
#  datetime.datetime(2024, 10, 10, 16, 12, 18, 437103),
#  datetime.datetime(2024, 10, 10, 16, 12, 18, 947478),
#  datetime.datetime(2024, 10, 10, 16, 12, 19, 497179),
#  datetime.datetime(2024, 10, 10, 16, 12, 20, 8433),
#  datetime.datetime(2024, 10, 10, 16, 12, 20, 578881),
#  datetime.datetime(2024, 10, 10, 16, 12, 21, 92063),
#  datetime.datetime(2024, 10, 10, 16, 12, 21, 633923),
#  datetime.datetime(2024, 10, 10, 16, 12, 22, 143167),
#  datetime.datetime(2024, 10, 10, 16, 12, 22, 713698),
#  datetime.datetime(2024, 10, 10, 16, 12, 23, 264628),
#  datetime.datetime(2024, 10, 10, 16, 12, 23, 781158),
#  datetime.datetime(2024, 10, 10, 16, 12, 24, 288981),
#  datetime.datetime(2024, 10, 10, 16, 12, 24, 800030),
#  datetime.datetime(2024, 10, 10, 16, 12, 25, 376284),
#  datetime.datetime(2024, 10, 10, 16, 12, 25, 920289),
#  datetime.datetime(2024, 10, 10, 16, 12, 26, 428270),
#  datetime.datetime(2024, 10, 10, 16, 12, 26, 940336),
#  datetime.datetime(2024, 10, 10, 16, 12, 27, 472564),
#  datetime.datetime(2024, 10, 10, 16, 12, 27, 985381),
#  datetime.datetime(2024, 10, 10, 16, 12, 28, 494092),
#  datetime.datetime(2024, 10, 10, 16, 12, 29, 3350),
#  datetime.datetime(2024, 10, 10, 16, 12, 29, 511092),
#  datetime.datetime(2024, 10, 10, 16, 12, 30, 54478),
#  datetime.datetime(2024, 10, 10, 16, 12, 30, 565908),
#  datetime.datetime(2024, 10, 10, 16, 12, 31, 74979),
#  datetime.datetime(2024, 10, 10, 16, 12, 31, 584669),
#  datetime.datetime(2024, 10, 10, 16, 12, 32, 93184),
#  datetime.datetime(2024, 10, 10, 16, 12, 32, 600722),
#  datetime.datetime(2024, 10, 10, 16, 12, 33, 108627),
#  datetime.datetime(2024, 10, 10, 16, 12, 33, 616834),
#  datetime.datetime(2024, 10, 10, 16, 12, 34, 125763),
#  datetime.datetime(2024, 10, 10, 16, 12, 34, 633269),
#  datetime.datetime(2024, 10, 10, 16, 12, 35, 141048),
#  datetime.datetime(2024, 10, 10, 16, 12, 35, 735337),
#  datetime.datetime(2024, 10, 10, 16, 12, 36, 244248),
#  datetime.datetime(2024, 10, 10, 16, 12, 36, 756977),
#  datetime.datetime(2024, 10, 10, 16, 12, 37, 264786),
#  datetime.datetime(2024, 10, 10, 16, 12, 37, 836686),
#  datetime.datetime(2024, 10, 10, 16, 12, 38, 345530),
#  datetime.datetime(2024, 10, 10, 16, 12, 38, 853294),
#  datetime.datetime(2024, 10, 10, 16, 12, 39, 466565),
#  datetime.datetime(2024, 10, 10, 16, 12, 39, 976185),
#  datetime.datetime(2024, 10, 10, 16, 12, 40, 520790),
#  datetime.datetime(2024, 10, 10, 16, 12, 41, 83352),
#  datetime.datetime(2024, 10, 10, 16, 12, 41, 593582),
#  datetime.datetime(2024, 10, 10, 16, 12, 42, 102219),
#  datetime.datetime(2024, 10, 10, 16, 12, 42, 611077),
#  datetime.datetime(2024, 10, 10, 16, 12, 43, 122751),
#  datetime.datetime(2024, 10, 10, 16, 12, 43, 708606),
#  datetime.datetime(2024, 10, 10, 16, 12, 44, 217302),
#  datetime.datetime(2024, 10, 10, 16, 12, 44, 821010),
#  datetime.datetime(2024, 10, 10, 16, 12, 45, 329352),
#  datetime.datetime(2024, 10, 10, 16, 12, 45, 930062),
#  datetime.datetime(2024, 10, 10, 16, 12, 46, 442259),
#  datetime.datetime(2024, 10, 10, 16, 12, 46, 954576),
#  datetime.datetime(2024, 10, 10, 16, 12, 47, 526035),
#  datetime.datetime(2024, 10, 10, 16, 12, 48, 100725),
#  datetime.datetime(2024, 10, 10, 16, 12, 48, 617069),
#  datetime.datetime(2024, 10, 10, 16, 12, 49, 125372),
#  datetime.datetime(2024, 10, 10, 16, 12, 49, 632929),
#  datetime.datetime(2024, 10, 10, 16, 12, 50, 244385),
#  datetime.datetime(2024, 10, 10, 16, 12, 50, 807830),
#  datetime.datetime(2024, 10, 10, 16, 12, 51, 332285),
#  datetime.datetime(2024, 10, 10, 16, 12, 51, 922896),
#  datetime.datetime(2024, 10, 10, 16, 12, 52, 431042),
#  datetime.datetime(2024, 10, 10, 16, 12, 52, 939832),
#  datetime.datetime(2024, 10, 10, 16, 12, 53, 447712),
#  datetime.datetime(2024, 10, 10, 16, 12, 54, 15556),
#  datetime.datetime(2024, 10, 10, 16, 12, 54, 523130),
#  datetime.datetime(2024, 10, 10, 16, 12, 55, 31393),
#  datetime.datetime(2024, 10, 10, 16, 12, 55, 540222),
#  datetime.datetime(2024, 10, 10, 16, 12, 56, 51022),
#  datetime.datetime(2024, 10, 10, 16, 12, 56, 576007),
#  datetime.datetime(2024, 10, 10, 16, 12, 57, 87281),
#  datetime.datetime(2024, 10, 10, 16, 12, 57, 601046),
#  datetime.datetime(2024, 10, 10, 16, 12, 58, 206623),
#  datetime.datetime(2024, 10, 10, 16, 12, 58, 715764),
#  datetime.datetime(2024, 10, 10, 16, 12, 59, 223274),
#  datetime.datetime(2024, 10, 10, 16, 12, 59, 788389),
#  datetime.datetime(2024, 10, 10, 16, 13, 0, 303046),
#  datetime.datetime(2024, 10, 10, 16, 13, 0, 813836),
#  datetime.datetime(2024, 10, 10, 16, 13, 1, 377959),
#  datetime.datetime(2024, 10, 10, 16, 13, 1, 887413),
#  datetime.datetime(2024, 10, 10, 16, 13, 2, 396289),
#  datetime.datetime(2024, 10, 10, 16, 13, 2, 904012),
#  datetime.datetime(2024, 10, 10, 16, 13, 3, 412835),
#  datetime.datetime(2024, 10, 10, 16, 13, 3, 920213),
#  datetime.datetime(2024, 10, 10, 16, 13, 4, 429562),
#  datetime.datetime(2024, 10, 10, 16, 13, 4, 938129),
#  datetime.datetime(2024, 10, 10, 16, 13, 5, 445615),
#  datetime.datetime(2024, 10, 10, 16, 13, 6, 25620),
#  datetime.datetime(2024, 10, 10, 16, 13, 6, 536554),
#  datetime.datetime(2024, 10, 10, 16, 13, 7, 49754),
#  datetime.datetime(2024, 10, 10, 16, 13, 7, 558186),
#  datetime.datetime(2024, 10, 10, 16, 13, 8, 66633),
#  datetime.datetime(2024, 10, 10, 16, 13, 8, 580350),
#  datetime.datetime(2024, 10, 10, 16, 13, 9, 89344),
#  datetime.datetime(2024, 10, 10, 16, 13, 9, 639193),
#  datetime.datetime(2024, 10, 10, 16, 13, 10, 149656),
#  datetime.datetime(2024, 10, 10, 16, 13, 10, 701213),
#  datetime.datetime(2024, 10, 10, 16, 13, 11, 219750),
#  datetime.datetime(2024, 10, 10, 16, 13, 11, 728611),
#  datetime.datetime(2024, 10, 10, 16, 13, 12, 237729),
#  datetime.datetime(2024, 10, 10, 16, 13, 12, 747287),
#  datetime.datetime(2024, 10, 10, 16, 13, 13, 307115),
#  datetime.datetime(2024, 10, 10, 16, 13, 13, 816178),
#  datetime.datetime(2024, 10, 10, 16, 13, 14, 324520),
#  datetime.datetime(2024, 10, 10, 16, 13, 14, 837934),
#  datetime.datetime(2024, 10, 10, 16, 13, 15, 349270),
#  datetime.datetime(2024, 10, 10, 16, 13, 15, 909038),
#  datetime.datetime(2024, 10, 10, 16, 13, 16, 442815),
#  datetime.datetime(2024, 10, 10, 16, 13, 16, 955379),
#  datetime.datetime(2024, 10, 10, 16, 13, 17, 466858),
#  datetime.datetime(2024, 10, 10, 16, 13, 18, 43663),
#  datetime.datetime(2024, 10, 10, 16, 13, 18, 553521),
#  datetime.datetime(2024, 10, 10, 16, 13, 19, 61398),
#  datetime.datetime(2024, 10, 10, 16, 13, 19, 569602),
#  datetime.datetime(2024, 10, 10, 16, 13, 20, 171193),
#  datetime.datetime(2024, 10, 10, 16, 13, 20, 682251),
#  datetime.datetime(2024, 10, 10, 16, 13, 21, 244669),
#  datetime.datetime(2024, 10, 10, 16, 13, 21, 753868),
#  datetime.datetime(2024, 10, 10, 16, 13, 22, 352306),
#  datetime.datetime(2024, 10, 10, 16, 13, 22, 913180),
#  datetime.datetime(2024, 10, 10, 16, 13, 23, 423219),
#  datetime.datetime(2024, 10, 10, 16, 13, 23, 932314),
#  datetime.datetime(2024, 10, 10, 16, 13, 24, 463036),
#  datetime.datetime(2024, 10, 10, 16, 13, 24, 979259),
#  datetime.datetime(2024, 10, 10, 16, 13, 25, 487687),
#  datetime.datetime(2024, 10, 10, 16, 13, 26, 295),
#  datetime.datetime(2024, 10, 10, 16, 13, 26, 553952),
#  datetime.datetime(2024, 10, 10, 16, 13, 27, 70243),
#  datetime.datetime(2024, 10, 10, 16, 13, 27, 580657),
#  datetime.datetime(2024, 10, 10, 16, 13, 28, 93646),
#  datetime.datetime(2024, 10, 10, 16, 13, 28, 642512),
#  datetime.datetime(2024, 10, 10, 16, 13, 29, 151881),
#  datetime.datetime(2024, 10, 10, 16, 13, 29, 671428),
#  datetime.datetime(2024, 10, 10, 16, 13, 30, 335024),
#  datetime.datetime(2024, 10, 10, 16, 13, 30, 843246),
#  datetime.datetime(2024, 10, 10, 16, 13, 31, 355492),
#  datetime.datetime(2024, 10, 10, 16, 13, 31, 925884),
#  datetime.datetime(2024, 10, 10, 16, 13, 32, 435350),
#  datetime.datetime(2024, 10, 10, 16, 13, 32, 943694),
#  datetime.datetime(2024, 10, 10, 16, 13, 33, 452422),
#  datetime.datetime(2024, 10, 10, 16, 13, 33, 963490),
#  datetime.datetime(2024, 10, 10, 16, 13, 34, 472006),
#  datetime.datetime(2024, 10, 10, 16, 13, 34, 980634),
#  datetime.datetime(2024, 10, 10, 16, 13, 35, 560624),
#  datetime.datetime(2024, 10, 10, 16, 13, 36, 110025),
#  datetime.datetime(2024, 10, 10, 16, 13, 36, 667138),
#  datetime.datetime(2024, 10, 10, 16, 13, 37, 221177),
#  datetime.datetime(2024, 10, 10, 16, 13, 37, 841921),
#  datetime.datetime(2024, 10, 10, 16, 13, 38, 403331),
#  datetime.datetime(2024, 10, 10, 16, 13, 38, 983472),
#  datetime.datetime(2024, 10, 10, 16, 13, 39, 494514),
#  datetime.datetime(2024, 10, 10, 16, 13, 40, 2797),
#  datetime.datetime(2024, 10, 10, 16, 13, 40, 520403),
#  datetime.datetime(2024, 10, 10, 16, 13, 41, 90336),
#  datetime.datetime(2024, 10, 10, 16, 13, 41, 609133),
#  datetime.datetime(2024, 10, 10, 16, 13, 42, 116771),
#  datetime.datetime(2024, 10, 10, 16, 13, 42, 625792),
#  datetime.datetime(2024, 10, 10, 16, 13, 43, 161507),
#  datetime.datetime(2024, 10, 10, 16, 13, 43, 668981),
#  datetime.datetime(2024, 10, 10, 16, 13, 44, 231373),
#  datetime.datetime(2024, 10, 10, 16, 13, 44, 740290),
#  datetime.datetime(2024, 10, 10, 16, 13, 45, 250702),
#  datetime.datetime(2024, 10, 10, 16, 13, 45, 759491),
#  datetime.datetime(2024, 10, 10, 16, 13, 46, 267489),
#  datetime.datetime(2024, 10, 10, 16, 13, 46, 775803),
#  datetime.datetime(2024, 10, 10, 16, 13, 47, 284004),
#  datetime.datetime(2024, 10, 10, 16, 13, 47, 792940),
#  datetime.datetime(2024, 10, 10, 16, 13, 48, 324172),
#  datetime.datetime(2024, 10, 10, 16, 13, 48, 877419),
#  datetime.datetime(2024, 10, 10, 16, 13, 49, 388633),
#  datetime.datetime(2024, 10, 10, 16, 13, 49, 949649),
#  datetime.datetime(2024, 10, 10, 16, 13, 50, 469500),
#  datetime.datetime(2024, 10, 10, 16, 13, 50, 979176),
#  datetime.datetime(2024, 10, 10, 16, 13, 51, 486962),
#  datetime.datetime(2024, 10, 10, 16, 13, 51, 996353),
#  datetime.datetime(2024, 10, 10, 16, 13, 52, 504840),
#  datetime.datetime(2024, 10, 10, 16, 13, 53, 54936),
#  datetime.datetime(2024, 10, 10, 16, 13, 53, 600045),
#  datetime.datetime(2024, 10, 10, 16, 13, 54, 172343),
#  datetime.datetime(2024, 10, 10, 16, 13, 54, 683473),
#  datetime.datetime(2024, 10, 10, 16, 13, 55, 211333),
#  datetime.datetime(2024, 10, 10, 16, 13, 55, 803202),
#  datetime.datetime(2024, 10, 10, 16, 13, 56, 315990),
#  datetime.datetime(2024, 10, 10, 16, 13, 56, 873082),
#  datetime.datetime(2024, 10, 10, 16, 13, 57, 467390),
#  datetime.datetime(2024, 10, 10, 16, 13, 57, 983686),
#  datetime.datetime(2024, 10, 10, 16, 13, 58, 491899),
#  datetime.datetime(2024, 10, 10, 16, 13, 59, 270),
#  datetime.datetime(2024, 10, 10, 16, 13, 59, 556484),
#  datetime.datetime(2024, 10, 10, 16, 14, 0, 66860),
#  datetime.datetime(2024, 10, 10, 16, 14, 0, 582826),
#  datetime.datetime(2024, 10, 10, 16, 14, 1, 127761),
#  datetime.datetime(2024, 10, 10, 16, 14, 1, 637038),
#  datetime.datetime(2024, 10, 10, 16, 14, 2, 180114),
#  datetime.datetime(2024, 10, 10, 16, 14, 2, 696422),
#  datetime.datetime(2024, 10, 10, 16, 14, 3, 204641),
#  datetime.datetime(2024, 10, 10, 16, 14, 3, 764540),
#  datetime.datetime(2024, 10, 10, 16, 14, 4, 274127),
#  datetime.datetime(2024, 10, 10, 16, 14, 4, 832685),
#  datetime.datetime(2024, 10, 10, 16, 14, 5, 349444),
#  datetime.datetime(2024, 10, 10, 16, 14, 5, 869684),
#  datetime.datetime(2024, 10, 10, 16, 14, 6, 378815),
#  datetime.datetime(2024, 10, 10, 16, 14, 6, 888277),
#  datetime.datetime(2024, 10, 10, 16, 14, 7, 397814),
#  datetime.datetime(2024, 10, 10, 16, 14, 7, 907752),
#  datetime.datetime(2024, 10, 10, 16, 14, 8, 563342),
#  datetime.datetime(2024, 10, 10, 16, 14, 9, 70617),
#  datetime.datetime(2024, 10, 10, 16, 14, 9, 580078),
#  datetime.datetime(2024, 10, 10, 16, 14, 10, 90051),
#  datetime.datetime(2024, 10, 10, 16, 14, 10, 598965),
#  datetime.datetime(2024, 10, 10, 16, 14, 11, 117699),
#  datetime.datetime(2024, 10, 10, 16, 14, 11, 700859),
#  datetime.datetime(2024, 10, 10, 16, 14, 12, 272634),
#  datetime.datetime(2024, 10, 10, 16, 14, 12, 781847),
#  datetime.datetime(2024, 10, 10, 16, 14, 13, 291517),
#  datetime.datetime(2024, 10, 10, 16, 14, 13, 832053),
#  datetime.datetime(2024, 10, 10, 16, 14, 14, 340215),
#  datetime.datetime(2024, 10, 10, 16, 14, 14, 849274),
#  datetime.datetime(2024, 10, 10, 16, 14, 15, 362964),
#  datetime.datetime(2024, 10, 10, 16, 14, 15, 871429),
#  datetime.datetime(2024, 10, 10, 16, 14, 16, 378919),
#  datetime.datetime(2024, 10, 10, 16, 14, 16, 890735),
#  datetime.datetime(2024, 10, 10, 16, 14, 17, 500122),
#  datetime.datetime(2024, 10, 10, 16, 14, 18, 8737),
#  datetime.datetime(2024, 10, 10, 16, 14, 18, 517619),
#  datetime.datetime(2024, 10, 10, 16, 14, 19, 105589),
#  datetime.datetime(2024, 10, 10, 16, 14, 19, 621509),
#  datetime.datetime(2024, 10, 10, 16, 14, 20, 130509),
#  datetime.datetime(2024, 10, 10, 16, 14, 20, 638896),
#  datetime.datetime(2024, 10, 10, 16, 14, 21, 146403),
#  datetime.datetime(2024, 10, 10, 16, 14, 21, 717580),
#  datetime.datetime(2024, 10, 10, 16, 14, 22, 226365),
#  datetime.datetime(2024, 10, 10, 16, 14, 22, 735218),
#  datetime.datetime(2024, 10, 10, 16, 14, 23, 242841),
#  datetime.datetime(2024, 10, 10, 16, 14, 23, 854209),
#  datetime.datetime(2024, 10, 10, 16, 14, 24, 369910),
#  datetime.datetime(2024, 10, 10, 16, 14, 24, 970659),
#  datetime.datetime(2024, 10, 10, 16, 14, 25, 484383),
#  datetime.datetime(2024, 10, 10, 16, 14, 25, 993863),
#  datetime.datetime(2024, 10, 10, 16, 14, 26, 504098),
#  datetime.datetime(2024, 10, 10, 16, 14, 27, 15095),
#  datetime.datetime(2024, 10, 10, 16, 14, 27, 607695),
#  datetime.datetime(2024, 10, 10, 16, 14, 28, 121325),
#  datetime.datetime(2024, 10, 10, 16, 14, 28, 637668),
#  datetime.datetime(2024, 10, 10, 16, 14, 29, 233878),
#  datetime.datetime(2024, 10, 10, 16, 14, 29, 741228),
#  datetime.datetime(2024, 10, 10, 16, 14, 30, 248928),
#  datetime.datetime(2024, 10, 10, 16, 14, 30, 757337),
#  datetime.datetime(2024, 10, 10, 16, 14, 31, 265407),
#  datetime.datetime(2024, 10, 10, 16, 14, 31, 776627),
#  datetime.datetime(2024, 10, 10, 16, 14, 32, 283904),
#  datetime.datetime(2024, 10, 10, 16, 14, 32, 791410),
#  datetime.datetime(2024, 10, 10, 16, 14, 33, 445711),
#  datetime.datetime(2024, 10, 10, 16, 14, 34, 16305),
#  datetime.datetime(2024, 10, 10, 16, 14, 34, 616666),
#  datetime.datetime(2024, 10, 10, 16, 14, 35, 124888),
#  datetime.datetime(2024, 10, 10, 16, 14, 35, 706594),
#  datetime.datetime(2024, 10, 10, 16, 14, 36, 220642),
#  datetime.datetime(2024, 10, 10, 16, 14, 36, 815281),
#  datetime.datetime(2024, 10, 10, 16, 14, 37, 326791),
#  datetime.datetime(2024, 10, 10, 16, 14, 37, 834583),
#  datetime.datetime(2024, 10, 10, 16, 14, 38, 345144),
#  datetime.datetime(2024, 10, 10, 16, 14, 38, 853272),
#  datetime.datetime(2024, 10, 10, 16, 14, 39, 419725),
#  datetime.datetime(2024, 10, 10, 16, 14, 39, 929321),
#  datetime.datetime(2024, 10, 10, 16, 14, 40, 486899),
#  datetime.datetime(2024, 10, 10, 16, 14, 41, 5545),
#  datetime.datetime(2024, 10, 10, 16, 14, 41, 571469),
#  datetime.datetime(2024, 10, 10, 16, 14, 42, 84292),
#  datetime.datetime(2024, 10, 10, 16, 14, 42, 593369),
#  datetime.datetime(2024, 10, 10, 16, 14, 43, 175180),
#  datetime.datetime(2024, 10, 10, 16, 14, 43, 809227),
#  datetime.datetime(2024, 10, 10, 16, 14, 44, 318426),
#  datetime.datetime(2024, 10, 10, 16, 14, 44, 827472),
#  datetime.datetime(2024, 10, 10, 16, 14, 45, 335945),
#  datetime.datetime(2024, 10, 10, 16, 14, 45, 847279),
#  datetime.datetime(2024, 10, 10, 16, 14, 46, 358418),
#  datetime.datetime(2024, 10, 10, 16, 14, 46, 867188),
#  datetime.datetime(2024, 10, 10, 16, 14, 47, 418108),
#  datetime.datetime(2024, 10, 10, 16, 14, 47, 935894),
#  datetime.datetime(2024, 10, 10, 16, 14, 48, 444529),
#  datetime.datetime(2024, 10, 10, 16, 14, 49, 232),
#  datetime.datetime(2024, 10, 10, 16, 14, 49, 509196),
#  datetime.datetime(2024, 10, 10, 16, 14, 50, 21662),
#  datetime.datetime(2024, 10, 10, 16, 14, 50, 529565),
#  datetime.datetime(2024, 10, 10, 16, 14, 51, 108456),
#  datetime.datetime(2024, 10, 10, 16, 14, 51, 697960),
#  datetime.datetime(2024, 10, 10, 16, 14, 52, 206959),
#  datetime.datetime(2024, 10, 10, 16, 14, 52, 715877),
#  datetime.datetime(2024, 10, 10, 16, 14, 53, 223843),
#  datetime.datetime(2024, 10, 10, 16, 14, 53, 734855),
#  datetime.datetime(2024, 10, 10, 16, 14, 54, 333956),
#  datetime.datetime(2024, 10, 10, 16, 14, 54, 924486),
#  datetime.datetime(2024, 10, 10, 16, 14, 55, 441726),
#  datetime.datetime(2024, 10, 10, 16, 14, 55, 958878),
#  datetime.datetime(2024, 10, 10, 16, 14, 56, 497953),
#  datetime.datetime(2024, 10, 10, 16, 14, 57, 6642),
#  datetime.datetime(2024, 10, 10, 16, 14, 57, 619217),
#  datetime.datetime(2024, 10, 10, 16, 14, 58, 129125),
#  datetime.datetime(2024, 10, 10, 16, 14, 58, 636997),
#  datetime.datetime(2024, 10, 10, 16, 14, 59, 144489),
#  datetime.datetime(2024, 10, 10, 16, 14, 59, 653981),
#  datetime.datetime(2024, 10, 10, 16, 15, 0, 161574),
#  datetime.datetime(2024, 10, 10, 16, 15, 0, 670220),
#  datetime.datetime(2024, 10, 10, 16, 15, 1, 178679),
#  datetime.datetime(2024, 10, 10, 16, 15, 1, 776342),
#  datetime.datetime(2024, 10, 10, 16, 15, 2, 285888),
#  datetime.datetime(2024, 10, 10, 16, 15, 2, 795703),
#  datetime.datetime(2024, 10, 10, 16, 15, 3, 396629),
#  datetime.datetime(2024, 10, 10, 16, 15, 3, 904547),
#  datetime.datetime(2024, 10, 10, 16, 15, 4, 512292),
#  datetime.datetime(2024, 10, 10, 16, 15, 5, 21093),
#  datetime.datetime(2024, 10, 10, 16, 15, 5, 531006),
#  datetime.datetime(2024, 10, 10, 16, 15, 6, 51055),
#  datetime.datetime(2024, 10, 10, 16, 15, 6, 559881),
#  datetime.datetime(2024, 10, 10, 16, 15, 7, 89885),
#  datetime.datetime(2024, 10, 10, 16, 15, 7, 633538),
#  datetime.datetime(2024, 10, 10, 16, 15, 8, 142207),
#  datetime.datetime(2024, 10, 10, 16, 15, 8, 650908),
#  datetime.datetime(2024, 10, 10, 16, 15, 9, 194934),
#  datetime.datetime(2024, 10, 10, 16, 15, 9, 710750),
#  datetime.datetime(2024, 10, 10, 16, 15, 10, 287798),
#  datetime.datetime(2024, 10, 10, 16, 15, 10, 804985),
#  datetime.datetime(2024, 10, 10, 16, 15, 11, 315711),
#  datetime.datetime(2024, 10, 10, 16, 15, 11, 823408),
#  datetime.datetime(2024, 10, 10, 16, 15, 12, 335278),
#  datetime.datetime(2024, 10, 10, 16, 15, 12, 842921),
#  datetime.datetime(2024, 10, 10, 16, 15, 13, 456954),
#  datetime.datetime(2024, 10, 10, 16, 15, 13, 965792),
#  datetime.datetime(2024, 10, 10, 16, 15, 14, 596567),
#  datetime.datetime(2024, 10, 10, 16, 15, 15, 107277),
#  datetime.datetime(2024, 10, 10, 16, 15, 15, 614545),
#  datetime.datetime(2024, 10, 10, 16, 15, 16, 122852),
#  datetime.datetime(2024, 10, 10, 16, 15, 16, 630675),
#  datetime.datetime(2024, 10, 10, 16, 15, 17, 149212),
#  datetime.datetime(2024, 10, 10, 16, 15, 17, 657453),
#  datetime.datetime(2024, 10, 10, 16, 15, 18, 164613),
#  datetime.datetime(2024, 10, 10, 16, 15, 18, 673100),
#  datetime.datetime(2024, 10, 10, 16, 15, 19, 180627),
#  datetime.datetime(2024, 10, 10, 16, 15, 19, 688537),
#  datetime.datetime(2024, 10, 10, 16, 15, 20, 199364),
#  datetime.datetime(2024, 10, 10, 16, 15, 20, 711422),
#  datetime.datetime(2024, 10, 10, 16, 15, 21, 223548),
#  datetime.datetime(2024, 10, 10, 16, 15, 21, 826615),
#  datetime.datetime(2024, 10, 10, 16, 15, 22, 335329),
#  datetime.datetime(2024, 10, 10, 16, 15, 22, 842790),
#  datetime.datetime(2024, 10, 10, 16, 15, 23, 351103),
#  datetime.datetime(2024, 10, 10, 16, 15, 23, 943358),
#  datetime.datetime(2024, 10, 10, 16, 15, 24, 461063),
#  datetime.datetime(2024, 10, 10, 16, 15, 24, 969080),
#  datetime.datetime(2024, 10, 10, 16, 15, 25, 477380),
#  datetime.datetime(2024, 10, 10, 16, 15, 25, 985934),
#  datetime.datetime(2024, 10, 10, 16, 15, 26, 586447),
#  datetime.datetime(2024, 10, 10, 16, 15, 27, 172081),
#  datetime.datetime(2024, 10, 10, 16, 15, 27, 757486),
#  datetime.datetime(2024, 10, 10, 16, 15, 28, 270932),
#  datetime.datetime(2024, 10, 10, 16, 15, 28, 781561),
#  datetime.datetime(2024, 10, 10, 16, 15, 29, 290260),
#  datetime.datetime(2024, 10, 10, 16, 15, 29, 798095),
#  datetime.datetime(2024, 10, 10, 16, 15, 30, 307242),
#  datetime.datetime(2024, 10, 10, 16, 15, 30, 815167),
#  datetime.datetime(2024, 10, 10, 16, 15, 31, 322777),
#  datetime.datetime(2024, 10, 10, 16, 15, 31, 832287),
#  datetime.datetime(2024, 10, 10, 16, 15, 32, 340917),
#  datetime.datetime(2024, 10, 10, 16, 15, 32, 849567),
#  datetime.datetime(2024, 10, 10, 16, 15, 33, 358257),
#  datetime.datetime(2024, 10, 10, 16, 15, 33, 868070),
#  datetime.datetime(2024, 10, 10, 16, 15, 34, 444214),
#  datetime.datetime(2024, 10, 10, 16, 15, 34, 957053),
#  datetime.datetime(2024, 10, 10, 16, 15, 35, 559990),
#  datetime.datetime(2024, 10, 10, 16, 15, 36, 75413),
#  datetime.datetime(2024, 10, 10, 16, 15, 36, 678103),
#  datetime.datetime(2024, 10, 10, 16, 15, 37, 193619),
#  datetime.datetime(2024, 10, 10, 16, 15, 37, 701337),
#  datetime.datetime(2024, 10, 10, 16, 15, 38, 212855),
#  datetime.datetime(2024, 10, 10, 16, 15, 38, 722938),
#  datetime.datetime(2024, 10, 10, 16, 15, 39, 269384),
#  datetime.datetime(2024, 10, 10, 16, 15, 39, 779174),
#  datetime.datetime(2024, 10, 10, 16, 15, 40, 288913),
#  datetime.datetime(2024, 10, 10, 16, 15, 40, 809501),
#  datetime.datetime(2024, 10, 10, 16, 15, 41, 317661),
#  datetime.datetime(2024, 10, 10, 16, 15, 41, 825222),
#  datetime.datetime(2024, 10, 10, 16, 15, 42, 420506),
#  datetime.datetime(2024, 10, 10, 16, 15, 42, 932955),
#  datetime.datetime(2024, 10, 10, 16, 15, 43, 441951),
#  datetime.datetime(2024, 10, 10, 16, 15, 44, 8232),
#  datetime.datetime(2024, 10, 10, 16, 15, 44, 520500),
#  datetime.datetime(2024, 10, 10, 16, 15, 45, 29629),
#  datetime.datetime(2024, 10, 10, 16, 15, 45, 601112),
#  datetime.datetime(2024, 10, 10, 16, 15, 46, 116532),
#  datetime.datetime(2024, 10, 10, 16, 15, 46, 624593),
#  datetime.datetime(2024, 10, 10, 16, 15, 47, 131978),
#  datetime.datetime(2024, 10, 10, 16, 15, 47, 644890),
#  datetime.datetime(2024, 10, 10, 16, 15, 48, 153610),
#  datetime.datetime(2024, 10, 10, 16, 15, 48, 661688),
#  datetime.datetime(2024, 10, 10, 16, 15, 49, 176278),
#  datetime.datetime(2024, 10, 10, 16, 15, 49, 748407),
#  datetime.datetime(2024, 10, 10, 16, 15, 50, 297720),
#  datetime.datetime(2024, 10, 10, 16, 15, 50, 806765),
#  datetime.datetime(2024, 10, 10, 16, 15, 51, 316612),
#  datetime.datetime(2024, 10, 10, 16, 15, 51, 826444),
#  datetime.datetime(2024, 10, 10, 16, 15, 52, 335449),
#  datetime.datetime(2024, 10, 10, 16, 15, 52, 914231),
#  datetime.datetime(2024, 10, 10, 16, 15, 53, 424787),
#  datetime.datetime(2024, 10, 10, 16, 15, 53, 932521),
#  datetime.datetime(2024, 10, 10, 16, 15, 54, 441170),
#  datetime.datetime(2024, 10, 10, 16, 15, 54, 950103),
#  datetime.datetime(2024, 10, 10, 16, 15, 55, 521006),
#  datetime.datetime(2024, 10, 10, 16, 15, 56, 125511),
#  datetime.datetime(2024, 10, 10, 16, 15, 56, 737328),
#  datetime.datetime(2024, 10, 10, 16, 15, 57, 252753),
#  datetime.datetime(2024, 10, 10, 16, 15, 57, 845023),
#  datetime.datetime(2024, 10, 10, 16, 15, 58, 353765),
#  datetime.datetime(2024, 10, 10, 16, 15, 58, 862109),
#  datetime.datetime(2024, 10, 10, 16, 15, 59, 455893),
#  datetime.datetime(2024, 10, 10, 16, 15, 59, 966373),
#  datetime.datetime(2024, 10, 10, 16, 16, 0, 475228),
#  datetime.datetime(2024, 10, 10, 16, 16, 1, 75575),
#  datetime.datetime(2024, 10, 10, 16, 16, 1, 672736),
#  datetime.datetime(2024, 10, 10, 16, 16, 2, 183973),
#  datetime.datetime(2024, 10, 10, 16, 16, 2, 740471),
#  datetime.datetime(2024, 10, 10, 16, 16, 3, 250991),
#  datetime.datetime(2024, 10, 10, 16, 16, 3, 820914),
#  datetime.datetime(2024, 10, 10, 16, 16, 4, 330802),
#  datetime.datetime(2024, 10, 10, 16, 16, 4, 905987),
#  datetime.datetime(2024, 10, 10, 16, 16, 5, 428253),
#  datetime.datetime(2024, 10, 10, 16, 16, 5, 936961),
#  datetime.datetime(2024, 10, 10, 16, 16, 6, 444756),
#  datetime.datetime(2024, 10, 10, 16, 16, 6, 952528),
#  datetime.datetime(2024, 10, 10, 16, 16, 7, 488145),
#  datetime.datetime(2024, 10, 10, 16, 16, 7, 996360),
#  datetime.datetime(2024, 10, 10, 16, 16, 8, 502995),
#  datetime.datetime(2024, 10, 10, 16, 16, 9, 10706),
#  datetime.datetime(2024, 10, 10, 16, 16, 9, 636443),
#  datetime.datetime(2024, 10, 10, 16, 16, 10, 154388),
#  datetime.datetime(2024, 10, 10, 16, 16, 10, 662723),
#  datetime.datetime(2024, 10, 10, 16, 16, 11, 172155),
#  datetime.datetime(2024, 10, 10, 16, 16, 11, 680286),
#  datetime.datetime(2024, 10, 10, 16, 16, 12, 188195),
#  datetime.datetime(2024, 10, 10, 16, 16, 12, 764821),
#  datetime.datetime(2024, 10, 10, 16, 16, 13, 277607),
#  datetime.datetime(2024, 10, 10, 16, 16, 13, 785849),
#  datetime.datetime(2024, 10, 10, 16, 16, 14, 294784),
#  datetime.datetime(2024, 10, 10, 16, 16, 14, 879425),
#  datetime.datetime(2024, 10, 10, 16, 16, 15, 395479),
#  datetime.datetime(2024, 10, 10, 16, 16, 15, 997939),
#  datetime.datetime(2024, 10, 10, 16, 16, 16, 506849),
#  datetime.datetime(2024, 10, 10, 16, 16, 17, 16900),
#  datetime.datetime(2024, 10, 10, 16, 16, 17, 533484),
#  datetime.datetime(2024, 10, 10, 16, 16, 18, 42527),
#  datetime.datetime(2024, 10, 10, 16, 16, 18, 587270),
#  datetime.datetime(2024, 10, 10, 16, 16, 19, 114368),
#  datetime.datetime(2024, 10, 10, 16, 16, 19, 622793),
#  datetime.datetime(2024, 10, 10, 16, 16, 20, 130718),
#  datetime.datetime(2024, 10, 10, 16, 16, 20, 637967),
#  datetime.datetime(2024, 10, 10, 16, 16, 21, 145902),
#  datetime.datetime(2024, 10, 10, 16, 16, 21, 663342),
#  datetime.datetime(2024, 10, 10, 16, 16, 22, 172908),
#  datetime.datetime(2024, 10, 10, 16, 16, 22, 680557),
#  datetime.datetime(2024, 10, 10, 16, 16, 23, 189143),
#  datetime.datetime(2024, 10, 10, 16, 16, 23, 779384),
#  datetime.datetime(2024, 10, 10, 16, 16, 24, 337771),
#  datetime.datetime(2024, 10, 10, 16, 16, 24, 846673),
#  datetime.datetime(2024, 10, 10, 16, 16, 25, 355739),
#  datetime.datetime(2024, 10, 10, 16, 16, 25, 864978),
#  datetime.datetime(2024, 10, 10, 16, 16, 26, 415395),
#  datetime.datetime(2024, 10, 10, 16, 16, 26, 979812),
#  datetime.datetime(2024, 10, 10, 16, 16, 27, 562560),
#  datetime.datetime(2024, 10, 10, 16, 16, 28, 71181),
#  datetime.datetime(2024, 10, 10, 16, 16, 28, 646830),
#  datetime.datetime(2024, 10, 10, 16, 16, 29, 170185),
#  datetime.datetime(2024, 10, 10, 16, 16, 29, 759222),
#  datetime.datetime(2024, 10, 10, 16, 16, 30, 266845),
#  datetime.datetime(2024, 10, 10, 16, 16, 30, 774955),
#  datetime.datetime(2024, 10, 10, 16, 16, 31, 286324),
#  datetime.datetime(2024, 10, 10, 16, 16, 31, 882869),
#  datetime.datetime(2024, 10, 10, 16, 16, 32, 392748),
#  datetime.datetime(2024, 10, 10, 16, 16, 32, 980145),
#  datetime.datetime(2024, 10, 10, 16, 16, 33, 494794),
#  datetime.datetime(2024, 10, 10, 16, 16, 34, 1977),
#  datetime.datetime(2024, 10, 10, 16, 16, 34, 510467),
#  datetime.datetime(2024, 10, 10, 16, 16, 35, 19169),
#  datetime.datetime(2024, 10, 10, 16, 16, 35, 526934),
#  datetime.datetime(2024, 10, 10, 16, 16, 36, 35190),
#  datetime.datetime(2024, 10, 10, 16, 16, 36, 543701),
#  datetime.datetime(2024, 10, 10, 16, 16, 37, 163280),
#  datetime.datetime(2024, 10, 10, 16, 16, 37, 677617),
#  datetime.datetime(2024, 10, 10, 16, 16, 38, 269912),
#  datetime.datetime(2024, 10, 10, 16, 16, 38, 779702),
#  datetime.datetime(2024, 10, 10, 16, 16, 39, 356092),
#  datetime.datetime(2024, 10, 10, 16, 16, 39, 868787),
#  datetime.datetime(2024, 10, 10, 16, 16, 40, 378442),
#  datetime.datetime(2024, 10, 10, 16, 16, 40, 967069),
#  datetime.datetime(2024, 10, 10, 16, 16, 41, 474872),
#  datetime.datetime(2024, 10, 10, 16, 16, 41, 982503),
#  datetime.datetime(2024, 10, 10, 16, 16, 42, 489948),
#  datetime.datetime(2024, 10, 10, 16, 16, 43, 81000),
#  datetime.datetime(2024, 10, 10, 16, 16, 43, 589347),
#  datetime.datetime(2024, 10, 10, 16, 16, 44, 186185),
#  datetime.datetime(2024, 10, 10, 16, 16, 44, 694793),
#  datetime.datetime(2024, 10, 10, 16, 16, 45, 203554),
#  datetime.datetime(2024, 10, 10, 16, 16, 45, 710894),
#  datetime.datetime(2024, 10, 10, 16, 16, 46, 220712),
#  datetime.datetime(2024, 10, 10, 16, 16, 46, 728852),
#  datetime.datetime(2024, 10, 10, 16, 16, 47, 236743),
#  datetime.datetime(2024, 10, 10, 16, 16, 47, 749605),
#  datetime.datetime(2024, 10, 10, 16, 16, 48, 259367),
#  datetime.datetime(2024, 10, 10, 16, 16, 48, 767144),
#  datetime.datetime(2024, 10, 10, 16, 16, 49, 274922),
#  datetime.datetime(2024, 10, 10, 16, 16, 49, 783295),
#  datetime.datetime(2024, 10, 10, 16, 16, 50, 291302),
#  datetime.datetime(2024, 10, 10, 16, 16, 50, 892398),
#  datetime.datetime(2024, 10, 10, 16, 16, 51, 400424),
#  datetime.datetime(2024, 10, 10, 16, 16, 51, 908640),
#  datetime.datetime(2024, 10, 10, 16, 16, 52, 418076),
#  datetime.datetime(2024, 10, 10, 16, 16, 52, 932340),
#  datetime.datetime(2024, 10, 10, 16, 16, 53, 484618),
#  datetime.datetime(2024, 10, 10, 16, 16, 53, 993157),
#  datetime.datetime(2024, 10, 10, 16, 16, 54, 504586),
#  datetime.datetime(2024, 10, 10, 16, 16, 55, 86803),
#  datetime.datetime(2024, 10, 10, 16, 16, 55, 643277),
#  datetime.datetime(2024, 10, 10, 16, 16, 56, 232415),
#  datetime.datetime(2024, 10, 10, 16, 16, 56, 741416),
#  datetime.datetime(2024, 10, 10, 16, 16, 57, 252445),
#  datetime.datetime(2024, 10, 10, 16, 16, 57, 765154),
#  datetime.datetime(2024, 10, 10, 16, 16, 58, 274607),
#  datetime.datetime(2024, 10, 10, 16, 16, 58, 854494),
#  datetime.datetime(2024, 10, 10, 16, 16, 59, 408259),
#  datetime.datetime(2024, 10, 10, 16, 16, 59, 920323),
#  datetime.datetime(2024, 10, 10, 16, 17, 0, 430268),
#  datetime.datetime(2024, 10, 10, 16, 17, 0, 939952),
#  datetime.datetime(2024, 10, 10, 16, 17, 1, 448281),
#  datetime.datetime(2024, 10, 10, 16, 17, 1, 956252),
#  datetime.datetime(2024, 10, 10, 16, 17, 2, 541441),
#  datetime.datetime(2024, 10, 10, 16, 17, 3, 129400),
#  datetime.datetime(2024, 10, 10, 16, 17, 3, 638901),
#  datetime.datetime(2024, 10, 10, 16, 17, 4, 146730),
#  datetime.datetime(2024, 10, 10, 16, 17, 4, 655222),
#  datetime.datetime(2024, 10, 10, 16, 17, 5, 164361),
#  datetime.datetime(2024, 10, 10, 16, 17, 5, 672977),
#  datetime.datetime(2024, 10, 10, 16, 17, 6, 260350),
#  datetime.datetime(2024, 10, 10, 16, 17, 6, 769856),
#  datetime.datetime(2024, 10, 10, 16, 17, 7, 277103),
#  datetime.datetime(2024, 10, 10, 16, 17, 7, 869689),
#  datetime.datetime(2024, 10, 10, 16, 17, 8, 379902),
#  datetime.datetime(2024, 10, 10, 16, 17, 8, 888622),
#  datetime.datetime(2024, 10, 10, 16, 17, 9, 397202),
#  datetime.datetime(2024, 10, 10, 16, 17, 9, 973943),
#  datetime.datetime(2024, 10, 10, 16, 17, 10, 564560),
#  datetime.datetime(2024, 10, 10, 16, 17, 11, 77279),
#  datetime.datetime(2024, 10, 10, 16, 17, 11, 585239),
#  datetime.datetime(2024, 10, 10, 16, 17, 12, 160604),
#  datetime.datetime(2024, 10, 10, 16, 17, 12, 720807),
#  datetime.datetime(2024, 10, 10, 16, 17, 13, 230146),
#  datetime.datetime(2024, 10, 10, 16, 17, 13, 740986),
#  datetime.datetime(2024, 10, 10, 16, 17, 14, 252482),
#  datetime.datetime(2024, 10, 10, 16, 17, 14, 854604),
#  datetime.datetime(2024, 10, 10, 16, 17, 15, 458276),
#  datetime.datetime(2024, 10, 10, 16, 17, 15, 968537),
#  datetime.datetime(2024, 10, 10, 16, 17, 16, 478107),
#  datetime.datetime(2024, 10, 10, 16, 17, 16, 985787),
#  datetime.datetime(2024, 10, 10, 16, 17, 17, 500670),
#  datetime.datetime(2024, 10, 10, 16, 17, 18, 56919),
#  datetime.datetime(2024, 10, 10, 16, 17, 18, 568947),
#  datetime.datetime(2024, 10, 10, 16, 17, 19, 78872),
#  datetime.datetime(2024, 10, 10, 16, 17, 19, 588744),
#  datetime.datetime(2024, 10, 10, 16, 17, 20, 140146),
#  datetime.datetime(2024, 10, 10, 16, 17, 20, 649075),
#  datetime.datetime(2024, 10, 10, 16, 17, 21, 159470),
#  datetime.datetime(2024, 10, 10, 16, 17, 21, 725803),
#  datetime.datetime(2024, 10, 10, 16, 17, 22, 281204),
#  datetime.datetime(2024, 10, 10, 16, 17, 22, 789994),
#  datetime.datetime(2024, 10, 10, 16, 17, 23, 298271),
#  datetime.datetime(2024, 10, 10, 16, 17, 23, 858056),
#  datetime.datetime(2024, 10, 10, 16, 17, 24, 369492),
#  datetime.datetime(2024, 10, 10, 16, 17, 24, 883218),
#  datetime.datetime(2024, 10, 10, 16, 17, 25, 392291),
#  datetime.datetime(2024, 10, 10, 16, 17, 25, 900637),
#  datetime.datetime(2024, 10, 10, 16, 17, 26, 408874),
#  datetime.datetime(2024, 10, 10, 16, 17, 26, 917175),
#  datetime.datetime(2024, 10, 10, 16, 17, 27, 436078),
#  datetime.datetime(2024, 10, 10, 16, 17, 27, 949160),
#  datetime.datetime(2024, 10, 10, 16, 17, 28, 456471),
#  datetime.datetime(2024, 10, 10, 16, 17, 28, 964458),
#  datetime.datetime(2024, 10, 10, 16, 17, 29, 472519),
#  datetime.datetime(2024, 10, 10, 16, 17, 29, 981459),
#  datetime.datetime(2024, 10, 10, 16, 17, 30, 491555),
#  datetime.datetime(2024, 10, 10, 16, 17, 31, 120),
#  datetime.datetime(2024, 10, 10, 16, 17, 31, 561865),
#  datetime.datetime(2024, 10, 10, 16, 17, 32, 71016),
#  datetime.datetime(2024, 10, 10, 16, 17, 32, 580303),
#  datetime.datetime(2024, 10, 10, 16, 17, 33, 88009),
#  datetime.datetime(2024, 10, 10, 16, 17, 33, 596715),
#  datetime.datetime(2024, 10, 10, 16, 17, 34, 108696),
#  datetime.datetime(2024, 10, 10, 16, 17, 34, 617912),
#  datetime.datetime(2024, 10, 10, 16, 17, 35, 125643),
#  datetime.datetime(2024, 10, 10, 16, 17, 35, 633758),
#  datetime.datetime(2024, 10, 10, 16, 17, 36, 142912),
#  datetime.datetime(2024, 10, 10, 16, 17, 36, 697132),
#  datetime.datetime(2024, 10, 10, 16, 17, 37, 224232),
#  datetime.datetime(2024, 10, 10, 16, 17, 37, 739070),
#  datetime.datetime(2024, 10, 10, 16, 17, 38, 249088),
#  datetime.datetime(2024, 10, 10, 16, 17, 38, 788285),
#  datetime.datetime(2024, 10, 10, 16, 17, 39, 297645),
#  datetime.datetime(2024, 10, 10, 16, 17, 39, 818506),
#  datetime.datetime(2024, 10, 10, 16, 17, 40, 326794),
#  datetime.datetime(2024, 10, 10, 16, 17, 40, 836060),
#  datetime.datetime(2024, 10, 10, 16, 17, 41, 343572),
#  datetime.datetime(2024, 10, 10, 16, 17, 41, 896870),
#  datetime.datetime(2024, 10, 10, 16, 17, 42, 488354),
#  datetime.datetime(2024, 10, 10, 16, 17, 43, 71921),
#  datetime.datetime(2024, 10, 10, 16, 17, 43, 582000),
#  datetime.datetime(2024, 10, 10, 16, 17, 44, 92220),
#  datetime.datetime(2024, 10, 10, 16, 17, 44, 601172),
#  datetime.datetime(2024, 10, 10, 16, 17, 45, 108996),
#  datetime.datetime(2024, 10, 10, 16, 17, 45, 618452),
#  datetime.datetime(2024, 10, 10, 16, 17, 46, 194416),
#  datetime.datetime(2024, 10, 10, 16, 17, 46, 703014),
#  datetime.datetime(2024, 10, 10, 16, 17, 47, 210822),
#  datetime.datetime(2024, 10, 10, 16, 17, 47, 724502),
#  datetime.datetime(2024, 10, 10, 16, 17, 48, 235653),
#  datetime.datetime(2024, 10, 10, 16, 17, 48, 743564),
#  datetime.datetime(2024, 10, 10, 16, 17, 49, 252181),
#  datetime.datetime(2024, 10, 10, 16, 17, 49, 774221),
#  datetime.datetime(2024, 10, 10, 16, 17, 50, 285522),
#  datetime.datetime(2024, 10, 10, 16, 17, 50, 794805),
#  datetime.datetime(2024, 10, 10, 16, 17, 51, 304578),
#  datetime.datetime(2024, 10, 10, 16, 17, 51, 813453),
#  datetime.datetime(2024, 10, 10, 16, 17, 52, 322767),
#  datetime.datetime(2024, 10, 10, 16, 17, 52, 830059),
#  datetime.datetime(2024, 10, 10, 16, 17, 53, 339244),
#  datetime.datetime(2024, 10, 10, 16, 17, 53, 905402),
#  datetime.datetime(2024, 10, 10, 16, 17, 54, 413461),
#  datetime.datetime(2024, 10, 10, 16, 17, 54, 921640),
#  datetime.datetime(2024, 10, 10, 16, 17, 55, 430097),
#  datetime.datetime(2024, 10, 10, 16, 17, 55, 938903),
#  datetime.datetime(2024, 10, 10, 16, 17, 56, 448572),
#  datetime.datetime(2024, 10, 10, 16, 17, 56, 958076),
#  datetime.datetime(2024, 10, 10, 16, 17, 57, 472850),
#  datetime.datetime(2024, 10, 10, 16, 17, 57, 981470),
#  datetime.datetime(2024, 10, 10, 16, 17, 58, 489432),
#  datetime.datetime(2024, 10, 10, 16, 17, 59, 101659),
#  datetime.datetime(2024, 10, 10, 16, 17, 59, 608775),
#  datetime.datetime(2024, 10, 10, 16, 18, 0, 116485),
#  datetime.datetime(2024, 10, 10, 16, 18, 0, 624197),
#  datetime.datetime(2024, 10, 10, 16, 18, 1, 151505),
#  datetime.datetime(2024, 10, 10, 16, 18, 1, 742029),
#  datetime.datetime(2024, 10, 10, 16, 18, 2, 305159),
#  datetime.datetime(2024, 10, 10, 16, 18, 2, 891030),
#  datetime.datetime(2024, 10, 10, 16, 18, 3, 458091),
#  datetime.datetime(2024, 10, 10, 16, 18, 4, 18714),
#  datetime.datetime(2024, 10, 10, 16, 18, 4, 530361),
#  datetime.datetime(2024, 10, 10, 16, 18, 5, 94977),
#  datetime.datetime(2024, 10, 10, 16, 18, 5, 603753),
#  datetime.datetime(2024, 10, 10, 16, 18, 6, 111281),
#  datetime.datetime(2024, 10, 10, 16, 18, 6, 724256),
#  datetime.datetime(2024, 10, 10, 16, 18, 7, 233185),
#  datetime.datetime(2024, 10, 10, 16, 18, 7, 745424),
#  datetime.datetime(2024, 10, 10, 16, 18, 8, 255290),
#  datetime.datetime(2024, 10, 10, 16, 18, 8, 789863),
#  datetime.datetime(2024, 10, 10, 16, 18, 9, 298447),
#  datetime.datetime(2024, 10, 10, 16, 18, 9, 864856),
#  datetime.datetime(2024, 10, 10, 16, 18, 10, 411074),
#  datetime.datetime(2024, 10, 10, 16, 18, 10, 921304),
#  datetime.datetime(2024, 10, 10, 16, 18, 11, 464539),
#  datetime.datetime(2024, 10, 10, 16, 18, 12, 52851),
#  datetime.datetime(2024, 10, 10, 16, 18, 12, 560143),
#  datetime.datetime(2024, 10, 10, 16, 18, 13, 69026),
#  datetime.datetime(2024, 10, 10, 16, 18, 13, 636684),
#  datetime.datetime(2024, 10, 10, 16, 18, 14, 147680),
#  datetime.datetime(2024, 10, 10, 16, 18, 14, 656329),
#  datetime.datetime(2024, 10, 10, 16, 18, 15, 164992),
#  datetime.datetime(2024, 10, 10, 16, 18, 15, 672800),
#  datetime.datetime(2024, 10, 10, 16, 18, 16, 183217),
#  datetime.datetime(2024, 10, 10, 16, 18, 16, 693929),
#  datetime.datetime(2024, 10, 10, 16, 18, 17, 202724),
#  datetime.datetime(2024, 10, 10, 16, 18, 17, 715570),
#  datetime.datetime(2024, 10, 10, 16, 18, 18, 224934),
#  datetime.datetime(2024, 10, 10, 16, 18, 18, 734306),
#  datetime.datetime(2024, 10, 10, 16, 18, 19, 243707),
#  datetime.datetime(2024, 10, 10, 16, 18, 19, 751651),
#  datetime.datetime(2024, 10, 10, 16, 18, 20, 259531),
#  datetime.datetime(2024, 10, 10, 16, 18, 20, 771839),
#  datetime.datetime(2024, 10, 10, 16, 18, 21, 342379),
#  datetime.datetime(2024, 10, 10, 16, 18, 21, 855463),
#  datetime.datetime(2024, 10, 10, 16, 18, 22, 443684),
#  datetime.datetime(2024, 10, 10, 16, 18, 22, 954874),
#  datetime.datetime(2024, 10, 10, 16, 18, 23, 465667),
#  datetime.datetime(2024, 10, 10, 16, 18, 23, 977611),
#  datetime.datetime(2024, 10, 10, 16, 18, 24, 584076),
#  datetime.datetime(2024, 10, 10, 16, 18, 25, 93667),
#  datetime.datetime(2024, 10, 10, 16, 18, 25, 604568),
#  datetime.datetime(2024, 10, 10, 16, 18, 26, 113314),
#  datetime.datetime(2024, 10, 10, 16, 18, 26, 624457),
#  datetime.datetime(2024, 10, 10, 16, 18, 27, 136554),
#  datetime.datetime(2024, 10, 10, 16, 18, 27, 643871),
#  datetime.datetime(2024, 10, 10, 16, 18, 28, 153040),
#  datetime.datetime(2024, 10, 10, 16, 18, 28, 670779),
#  datetime.datetime(2024, 10, 10, 16, 18, 29, 181974),
#  datetime.datetime(2024, 10, 10, 16, 18, 29, 690603),
#  datetime.datetime(2024, 10, 10, 16, 18, 30, 287898),
#  datetime.datetime(2024, 10, 10, 16, 18, 30, 808776),
#  datetime.datetime(2024, 10, 10, 16, 18, 31, 317617),
#  datetime.datetime(2024, 10, 10, 16, 18, 31, 826314),
#  ...]

# %%
file_list = sorted(glob.glob(f'{folder}/*.npz'))
len(file_list)
data = np.load(file_list[0])
pos = data['pos'][0]

all_mags = [np.array([0,0,0])]
for x in range(len(file_list)):
    try:
        data = np.load(file_list[x])
    except:
        display(file_list[x])
    mags = data['mags']
    all_mags = np.append(all_mags, mags[0], axis=0)
    pos = data['pos'][0]
    B = np.mean(mags, axis=0)
    mags_stdev = np.std(mags, axis=0)
all_mags = np.delete(all_mags, 0, axis=0)

bx = all_mags[:,0]
by = all_mags[:,1]
bz = all_mags[:,2]

# %%
bx7 = []
by7 = []
bz7 = []
for x in range(len(bx)):
    if x % 16 == 7:
        bx7.append(bx[x])
        by7.append(by[x])
        bz7.append(bz[x])
print(bx7)
print(by7)
print(bz7)
print(pos)
# Out:
# [-0.2091, -0.2079, -0.20879999999999999, -0.20729999999999998, -0.2082, -0.2079, -0.2067, -0.2082, -0.2061, -0.2079, -0.2094, -0.2082, -0.2085, -0.207, -0.2079, -0.207, -0.2079, -0.2082, -0.2085, -0.2079, -0.2079, -0.2076, -0.207, -0.2091, -0.2079, -0.2085, -0.2067, -0.2085, -0.2076, -0.2076, -0.20879999999999999, -0.2076, -0.2079, -0.2091, -0.2079, -0.20879999999999999, -0.2082, -0.2067, -0.2076, -0.2064, -0.2091, -0.2085, -0.2079, -0.207, -0.20879999999999999, -0.20879999999999999, -0.2094, -0.20879999999999999, -0.20729999999999998, -0.2082, -0.2097, -0.2076, -0.20729999999999998, -0.2091, -0.2067, -0.20879999999999999, -0.20729999999999998, -0.2079, -0.2094, -0.2094, -0.2094, -0.2079, -0.2079, -0.2082, -0.2064, -0.2079, -0.2085, -0.2082, -0.2076, -0.2064, -0.2085, -0.2085, -0.2082, -0.2076, -0.2082, -0.2082, -0.2082, -0.2079, -0.2079, -0.207, -0.20879999999999999, -0.2079, -0.2076, -0.2097, -0.207, -0.2079, -0.2079, -0.20729999999999998, -0.2079, -0.20879999999999999, -0.2076, -0.2085, -0.2091, -0.2094, -0.2076, -0.2076, -0.2079, -0.2091, -0.2076, -0.2064, -0.21059999999999998, -0.2082, -0.2076, -0.207, -0.2091, -0.2085, -0.2076, -0.2085, -0.2082, -0.2079, -0.2085, -0.2082, -0.2076, -0.2085, -0.21, -0.20729999999999998, -0.2091, -0.2094, -0.2061, -0.20729999999999998, -0.2082, -0.2082, -0.2094, -0.20879999999999999, -0.2085, -0.20879999999999999, -0.2097, -0.2082, -0.2085, -0.2094, -0.2097, -0.2091, -0.2091, -0.2079, -0.2094, -0.2079, -0.2091, -0.2082, -0.2085, -0.2085, -0.2109, -0.2091, -0.2082, -0.2094, -0.2082, -0.2082, -0.2085, -0.2079, -0.2094, -0.2091, -0.2076, -0.21, -0.2085, -0.21059999999999998, -0.2079, -0.21, -0.2082, -0.2067, -0.20729999999999998, -0.20879999999999999, -0.2082, -0.20879999999999999, -0.2082, -0.2094, -0.2091, -0.2085, -0.2091, -0.2103, -0.2097, -0.2112, -0.2115, -0.2109, -0.213, -0.2133, -0.2139, -0.21359999999999998, -0.2109, -0.2082, -0.2112, -0.21, -0.2094, -0.2067, -0.20729999999999998, -0.2055, -0.2055, -0.2046, -0.2046, -0.2016, -0.2022, -0.20129999999999998, -0.19979999999999998, -0.2001, -0.1989, -0.2007, -0.19829999999999998, -0.19619999999999999, -0.1965, -0.19529999999999997, -0.19529999999999997, -0.19229999999999997, -0.1935, -0.1911, -0.1926, -0.1911, -0.1911, -0.1896, -0.1899, -0.1896, -0.1896, -0.1878, -0.1869, -0.1848, -0.1875, -0.1863, -0.186, -0.1851, -0.1851, -0.18569999999999998, -0.1848, -0.1851, -0.18419999999999997, -0.1851, -0.18419999999999997, -0.1833, -0.1863, -0.18359999999999999, -0.1833, -0.18209999999999998, -0.18359999999999999, -0.1833, -0.18359999999999999, -0.1833, -0.1812, -0.1803, -0.1797, -0.17909999999999998, -0.1812, -0.1812, -0.1794, -0.1785, -0.1794, -0.177, -0.1776, -0.1767, -0.1767, -0.1764, -0.1761, -0.1761, -0.17579999999999998, -0.1749, -0.1749, -0.1746, -0.17429999999999998, -0.1752, -0.1749, -0.17579999999999998, -0.1752, -0.1737, -0.1719, -0.1755, -0.174, -0.17429999999999998, -0.1752, -0.1737, -0.1752, -0.1746, -0.1755, -0.1755, -0.1749, -0.1755, -0.17279999999999998, -0.1746, -0.1764, -0.1746, -0.1755, -0.174, -0.1746, -0.174, -0.1746, -0.17429999999999998, -0.1755, -0.1749, -0.1746, -0.1761, -0.17579999999999998, -0.1779, -0.1752, -0.1746, -0.1725, -0.1755, -0.1752, -0.177, -0.1749, -0.17429999999999998, -0.1764, -0.1737, -0.1752, -0.1755, -0.1752, -0.17429999999999998, -0.1746, -0.1746, -0.1761, -0.1752, -0.1767, -0.1764, -0.1752, -0.1755, -0.1761, -0.1755, -0.1749, -0.1761, -0.177, -0.1779, -0.17729999999999999, -0.17729999999999999, -0.1788, -0.1797, -0.1803, -0.18059999999999998, -0.18, -0.1809, -0.1827, -0.18209999999999998, -0.1824, -0.183, -0.1827, -0.1833, -0.186, -0.1854, -0.1866, -0.1869, -0.186, -0.1875, -0.1845, -0.1869, -0.1854, -0.186, -0.1848, -0.1875, -0.18719999999999998, -0.1878, -0.1884, -0.1878, -0.1884, -0.18869999999999998, -0.1893, -0.1896, -0.189, -0.1869, -0.1884, -0.19019999999999998, -0.1884, -0.19079999999999997, -0.1905, -0.189, -0.19140000000000001, -0.19140000000000001, -0.1911, -0.1935, -0.192, -0.1935, -0.192 ...
# [0.1851, 0.1851, 0.1851, 0.1851, 0.1848, 0.18419999999999997, 0.1845, 0.18569999999999998, 0.1827, 0.186, 0.1854, 0.1854, 0.18419999999999997, 0.18359999999999999, 0.18419999999999997, 0.1839, 0.1833, 0.1839, 0.1854, 0.1848, 0.18359999999999999, 0.1845, 0.186, 0.1848, 0.1851, 0.18419999999999997, 0.186, 0.1851, 0.1848, 0.1848, 0.1827, 0.1848, 0.1863, 0.1854, 0.1863, 0.1845, 0.1854, 0.1845, 0.18419999999999997, 0.186, 0.18569999999999998, 0.1854, 0.1851, 0.1839, 0.1863, 0.1851, 0.18359999999999999, 0.1845, 0.1854, 0.1854, 0.1848, 0.186, 0.18419999999999997, 0.18359999999999999, 0.18419999999999997, 0.18359999999999999, 0.18359999999999999, 0.186, 0.1845, 0.1845, 0.1845, 0.1848, 0.18569999999999998, 0.1833, 0.18419999999999997, 0.18419999999999997, 0.1845, 0.18419999999999997, 0.1845, 0.1854, 0.1875, 0.1851, 0.18569999999999998, 0.1854, 0.18419999999999997, 0.1845, 0.1845, 0.1863, 0.1839, 0.1839, 0.1851, 0.1827, 0.1833, 0.1845, 0.18569999999999998, 0.1854, 0.1845, 0.18419999999999997, 0.1845, 0.1848, 0.1854, 0.1845, 0.1845, 0.1845, 0.1845, 0.186, 0.1851, 0.1848, 0.1851, 0.1854, 0.186, 0.1848, 0.1848, 0.1851, 0.1848, 0.18419999999999997, 0.186, 0.1845, 0.1851, 0.1845, 0.18359999999999999, 0.1845, 0.18569999999999998, 0.18359999999999999, 0.1845, 0.1845, 0.18419999999999997, 0.1866, 0.1848, 0.1845, 0.1851, 0.18359999999999999, 0.1839, 0.1845, 0.1848, 0.18419999999999997, 0.1845, 0.1848, 0.1839, 0.18419999999999997, 0.1848, 0.1839, 0.1848, 0.1839, 0.1833, 0.1839, 0.18359999999999999, 0.18419999999999997, 0.1863, 0.1854, 0.18569999999999998, 0.1854, 0.1833, 0.1845, 0.1854, 0.18359999999999999, 0.1845, 0.1854, 0.1839, 0.1848, 0.18569999999999998, 0.186, 0.18359999999999999, 0.1839, 0.1851, 0.1845, 0.1854, 0.1845, 0.1854, 0.1851, 0.1851, 0.18419999999999997, 0.1845, 0.1854, 0.1863, 0.1851, 0.1845, 0.1863, 0.18419999999999997, 0.18209999999999998, 0.1848, 0.18419999999999997, 0.1827, 0.18209999999999998, 0.1833, 0.1839, 0.18419999999999997, 0.1833, 0.1854, 0.1851, 0.18719999999999998, 0.1869, 0.1869, 0.1869, 0.1875, 0.1896, 0.18869999999999998, 0.1881, 0.1896, 0.19019999999999998, 0.1896, 0.1899, 0.1884, 0.1899, 0.1905, 0.1896, 0.1911, 0.1896, 0.1899, 0.19079999999999997, 0.19229999999999997, 0.19140000000000001, 0.1905, 0.19140000000000001, 0.19169999999999998, 0.1911, 0.192, 0.19290000000000002, 0.1911, 0.19079999999999997, 0.1911, 0.19140000000000001, 0.19169999999999998, 0.1926, 0.1911, 0.19229999999999997, 0.19229999999999997, 0.1905, 0.19379999999999997, 0.19169999999999998, 0.192, 0.19229999999999997, 0.19019999999999998, 0.1911, 0.19229999999999997, 0.19169999999999998, 0.1905, 0.19319999999999998, 0.192, 0.192, 0.1926, 0.19379999999999997, 0.19229999999999997, 0.1926, 0.1926, 0.1926, 0.19440000000000002, 0.1926, 0.1926, 0.192, 0.1935, 0.19379999999999997, 0.19590000000000002, 0.1926, 0.1935, 0.19440000000000002, 0.1935, 0.19229999999999997, 0.1935, 0.192, 0.19440000000000002, 0.1941, 0.19469999999999998, 0.1935, 0.19319999999999998, 0.192, 0.19379999999999997, 0.19229999999999997, 0.1941, 0.1926, 0.19290000000000002, 0.19229999999999997, 0.19290000000000002, 0.19140000000000001, 0.19440000000000002, 0.1941, 0.192, 0.1935, 0.1941, 0.19229999999999997, 0.1935, 0.19169999999999998, 0.19319999999999998, 0.1935, 0.19379999999999997, 0.19290000000000002, 0.19440000000000002, 0.19140000000000001, 0.1941, 0.192, 0.19319999999999998, 0.19319999999999998, 0.19290000000000002, 0.19379999999999997, 0.1926, 0.1926, 0.19379999999999997, 0.1935, 0.19290000000000002, 0.19140000000000001, 0.1935, 0.19229999999999997, 0.19379999999999997, 0.1935, 0.1911, 0.19290000000000002, 0.19379999999999997, 0.1935, 0.19319999999999998, 0.19319999999999998, 0.19440000000000002, 0.1941, 0.1926, 0.1926, 0.19290000000000002, 0.1941, 0.1941, 0.19290000000000002, 0.1935, 0.19140000000000001, 0.19290000000000002, 0.192, 0.19140000000000001, 0.19079999999999997, 0.192, 0.189, 0.192, 0.19169999999999998, 0.1884, 0.1905, 0.192, 0.19019999999999998, 0.1896, 0.1905, 0 ...
# [0.24684, 0.248292, 0.24684, 0.247808, 0.249744, 0.24684, 0.248292, 0.247324, 0.247808, 0.249744, 0.247808, 0.248292, 0.247808, 0.247324, 0.245388, 0.250712, 0.248292, 0.24877599999999997, 0.247808, 0.249744, 0.24587199999999998, 0.247808, 0.24877599999999997, 0.248292, 0.24684, 0.24925999999999998, 0.248292, 0.24587199999999998, 0.242968, 0.24684, 0.24925999999999998, 0.245388, 0.247324, 0.246356, 0.245388, 0.248292, 0.248292, 0.246356, 0.24490399999999998, 0.249744, 0.247808, 0.247324, 0.247808, 0.248292, 0.247808, 0.246356, 0.250712, 0.24684, 0.24877599999999997, 0.248292, 0.246356, 0.24684, 0.24877599999999997, 0.249744, 0.247808, 0.247324, 0.243936, 0.247808, 0.247324, 0.245388, 0.24925999999999998, 0.247324, 0.247324, 0.247324, 0.248292, 0.248292, 0.24684, 0.245388, 0.248292, 0.247808, 0.248292, 0.24587199999999998, 0.24684, 0.24684, 0.24684, 0.247808, 0.248292, 0.24490399999999998, 0.247324, 0.249744, 0.248292, 0.249744, 0.24587199999999998, 0.24877599999999997, 0.24684, 0.249744, 0.24684, 0.24684, 0.24877599999999997, 0.247324, 0.247808, 0.24684, 0.245388, 0.24684, 0.247808, 0.247324, 0.246356, 0.24684, 0.249744, 0.24684, 0.248292, 0.247324, 0.24684, 0.247808, 0.247808, 0.247808, 0.247324, 0.245388, 0.247324, 0.24587199999999998, 0.24684, 0.248292, 0.247324, 0.247324, 0.24587199999999998, 0.24925999999999998, 0.247324, 0.247324, 0.247324, 0.24684, 0.24684, 0.247808, 0.247324, 0.247324, 0.246356, 0.24490399999999998, 0.24877599999999997, 0.248292, 0.24877599999999997, 0.247324, 0.248292, 0.246356, 0.248292, 0.247324, 0.247808, 0.247808, 0.24877599999999997, 0.247324, 0.245388, 0.247324, 0.24587199999999998, 0.24684, 0.248292, 0.247324, 0.24684, 0.24877599999999997, 0.248292, 0.247808, 0.247808, 0.24684, 0.248292, 0.247808, 0.24587199999999998, 0.24684, 0.24684, 0.24442, 0.249744, 0.248292, 0.250228, 0.247808, 0.247324, 0.24587199999999998, 0.247324, 0.24877599999999997, 0.247324, 0.247324, 0.246356, 0.247808, 0.24877599999999997, 0.252164, 0.252648, 0.252164, 0.253132, 0.2541, 0.2541, 0.2541, 0.250712, 0.248292, 0.24877599999999997, 0.247808, 0.24877599999999997, 0.24442, 0.247808, 0.245388, 0.240548, 0.243936, 0.23958, 0.240064, 0.23812799999999998, 0.23958, 0.236192, 0.236192, 0.232804, 0.235224, 0.232804, 0.233288, 0.23038399999999998, 0.234256, 0.231836, 0.2299, 0.227964, 0.22748, 0.22699599999999998, 0.22506, 0.228932, 0.223124, 0.22506, 0.22022, 0.223608, 0.220704, 0.222156, 0.22022, 0.21925199999999997, 0.22263999999999998, 0.219736, 0.21925199999999997, 0.22263999999999998, 0.22022, 0.219736, 0.2178, 0.219736, 0.2178, 0.2178, 0.2178, 0.215864, 0.21634799999999998, 0.216832, 0.21828399999999998, 0.217316, 0.216832, 0.21441200000000002, 0.21199199999999999, 0.215864, 0.21489599999999998, 0.212476, 0.213444, 0.21538, 0.21054, 0.212476, 0.21199199999999999, 0.210056, 0.20860399999999998, 0.209572, 0.205216, 0.20666800000000002, 0.20860399999999998, 0.20715199999999998, 0.2057, 0.20860399999999998, 0.20424799999999999, 0.20860399999999998, 0.20812, 0.206184, 0.20715199999999998, 0.210056, 0.21054, 0.20715199999999998, 0.209088, 0.20666800000000002, 0.209572, 0.20666800000000002, 0.2057, 0.20860399999999998, 0.205216, 0.207636, 0.20715199999999998, 0.207636, 0.209088, 0.204732, 0.20424799999999999, 0.20715199999999998, 0.20715199999999998, 0.20715199999999998, 0.207636, 0.20715199999999998, 0.20812, 0.20812, 0.20812, 0.20715199999999998, 0.20424799999999999, 0.20812, 0.209088, 0.209088, 0.206184, 0.204732, 0.204732, 0.20860399999999998, 0.20812, 0.20715199999999998, 0.206184, 0.20860399999999998, 0.20666800000000002, 0.20666800000000002, 0.20812, 0.21054, 0.205216, 0.20812, 0.20715199999999998, 0.20860399999999998, 0.2057, 0.20666800000000002, 0.20812, 0.20666800000000002, 0.2057, 0.2057, 0.206184, 0.20666800000000002, 0.20860399999999998, 0.20860399999999998, 0.206184, 0.209088, 0.20812, 0.209572, 0.20812, 0.209572, 0.209572, 0.209088, 0.212476, 0.21199199999999999, 0.21295999999999998, 0.212476, 0.21489599999999998, ...
# [[ 6.75 -6.75  0.  ]
#  [ 2.25 -6.75  0.  ]
#  [-2.25 -6.75  0.  ]
#  [-6.75 -6.75  0.  ]
#  [ 6.75 -2.25  0.  ]
#  [ 2.25 -2.25  0.  ]
#  [-2.25 -2.25  0.  ]
#  [-6.75 -2.25  0.  ]
#  [ 6.75  2.25  0.  ]
#  [ 2.25  2.25  0.  ]
#  [-2.25  2.25  0.  ]
#  [-6.75  2.25  0.  ]
#  [ 6.75  6.75  0.  ]
#  [ 2.25  6.75  0.  ]
#  [-2.25  6.75  0.  ]
#  [-6.75  6.75  0.  ]]

# %%
index = np.array(range(len(bx7)))
measuredbx = go.Scatter(x=timestamps, y=bx7, mode='markers')
layoutbx = go.Layout(title='b_x over time')
figbx = go.Figure(data=[measuredbx], layout=layoutbx)
figbx.update_yaxes(scaleanchor='y')
figbx.update_layout(
    xaxis_title="Time",
    yaxis_title="b_x [mT]"
)
figbx.show()

# %%
measuredby = go.Scatter(x=corrected_timestamps, y=by7, mode='markers')
layoutby = go.Layout(title='b_y over time')
figby = go.Figure(data=[measuredby], layout=layoutby)
figby.update_yaxes(scaleanchor='y')
figby.update_layout(
    xaxis_title="Time",
    yaxis_title="b_y [mT]"
)
figby.show()

# %%
measuredbz = go.Scatter(x=corrected_timestamps, y=bz7, mode='markers')
layoutbz = go.Layout(title='b_z over time')
figbz = go.Figure(data=[measuredbz], layout=layoutbz)
figbz.update_yaxes(scaleanchor='y')
figbz.update_layout(
    xaxis_title="Time",
    yaxis_title="b_z [mT]"
)
figbz.show()

# %%
# Specify the Excel file name (replace with your actual file name)
file = 'Shift_data_10102024gk.txt'

# Create the full file path
file_path = os.path.join('..', file)

# Read the Excel file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=',', na_values="        NaN")

df.dropna(inplace=True)
df[['X', 'Y', 'Z', 'Displacement [mm]']] = df[['X', 'Y', 'Z', 'Displacement [mm]']].apply(pd.to_numeric,errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%dT%H:%M:%S.%f')
df['datetime'] = df.loc[0:,'Time'].dt.time


print(df)
hdmm_time = df['Time']
hdmm_disp = df.loc[0:,'Displacement [mm]']
hdmm_x = df.loc[0:, 'X']
hdmm_y = df.loc[0:, 'Y']
hdmm_z = df.loc[0:, 'Z']
print(hdmm_time)
# Out:
#                         Time     X     Y     Z  Displacement [mm]  \
# 4    2024-10-10 16:08:00.133  0.00  0.00  0.00               0.00
# 5    2024-10-10 16:08:00.649  0.01 -0.00 -0.04               0.04
# 6    2024-10-10 16:08:01.167  0.01 -0.01 -0.02               0.03
# 7    2024-10-10 16:08:01.666  0.01 -0.01 -0.03               0.03
# 8    2024-10-10 16:08:02.183  0.01  0.00 -0.02               0.02
# ...                      ...   ...   ...   ...                ...
# 5967 2024-10-10 16:59:29.787  0.01 -0.01  0.04               0.06
# 5968 2024-10-10 16:59:30.304  0.01 -0.03  0.00               0.03
# 5969 2024-10-10 16:59:30.819  0.00 -0.04  0.03               0.06
# 5970 2024-10-10 16:59:31.369 -0.01 -0.04  0.01               0.04
# 5971 2024-10-10 16:59:31.918 -0.01 -0.01  0.04               0.08
#
#              datetime
# 4     16:08:00.133000
# 5     16:08:00.649000
# 6     16:08:01.167000
# 7     16:08:01.666000
# 8     16:08:02.183000
# ...               ...
# 5967  16:59:29.787000
# 5968  16:59:30.304000
# 5969  16:59:30.819000
# 5970  16:59:31.369000
# 5971  16:59:31.918000
#
# [5853 rows x 6 columns]
# 4      2024-10-10 16:08:00.133
# 5      2024-10-10 16:08:00.649
# 6      2024-10-10 16:08:01.167
# 7      2024-10-10 16:08:01.666
# 8      2024-10-10 16:08:02.183
#                  ...
# 5967   2024-10-10 16:59:29.787
# 5968   2024-10-10 16:59:30.304
# 5969   2024-10-10 16:59:30.819
# 5970   2024-10-10 16:59:31.369
# 5971   2024-10-10 16:59:31.918
# Name: Time, Length: 5853, dtype: datetime64[ns]

# %%
rel_loc_predx = [x - locpred[0,0] for x in locpred[:,0]]
rel_loc_predy = [x - locpred[0,1] for x in locpred[:,1]]
rel_loc_predz = [x - locpred[0,2] for x in locpred[:,2]]


dispx = np.array(rel_loc_predx)
dispy = np.array(rel_loc_predy)
dispz = np.array(rel_loc_predz)
disp = np.sqrt(dispx**2+dispy**2+dispz**2)

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(corrected_timestamps, disp, label='MLX')
plt.scatter(hdmm_time, hdmm_disp, label='HDMM')
#plt.scatter(hdmm_time[a:b], hdmm_disp2)
# Set x-axis labels to show only the time
# Format the x-axis to show date and time properly
plt.gcf().autofmt_xdate()  # Auto-format the dates on the x-axis
plt.xlabel('Timestamp')
plt.ylabel('Total Displacement (mm)')
plt.ylim(-1, 6)
plt.title('Total Displacement')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(corrected_timestamps, rel_loc_predy, label='MLX')
plt.scatter(hdmm_time, hdmm_x, label='HDMM')
plt.gcf().autofmt_xdate()  # Auto-format the dates on the x-axis
plt.xlabel('Timestamp')
plt.ylabel('X (mm)')
plt.ylim([-1,6])
plt.title('HDMM X vs Sensor Y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(corrected_timestamps, -np.array(rel_loc_predz), label='MLX')
plt.scatter(hdmm_time, hdmm_y, label='HDMM')
plt.gcf().autofmt_xdate()  # Auto-format the dates on the x-axis
plt.xlabel('Timestamp')
plt.ylabel('Distance (mm)')
plt.ylim(-1,3)
plt.title('HDMM Y vs Sensor Z Comparison')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(corrected_timestamps, rel_loc_predx, label='MLX')
plt.scatter(hdmm_time, hdmm_z, label='HDMM')
plt.gcf().autofmt_xdate()  # Auto-format the dates on the x-axis
plt.xlabel('Timestamp')
plt.ylabel('Z (mm)')
plt.title('HDMM Z vs Sensor X Comparison')
plt.grid(True)
plt.legend()
plt.show()
