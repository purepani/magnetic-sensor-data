# %%
import glob
import numpy as np
import scipy as sp
import einops as eo
import matplotlib.pyplot as plt
import math
import plotly.graph_objects as go
from scipy.spatial.transform import Rotation
import magpylib as magpy
import os
import pandas as pd
from datetime import timedelta
import sys
from datetime import datetime

M0 = 1480 #mT
shape = [5*25.4/16, 25.4/8] #radius and height
x0 = np.array([0,0,10, 0,0,1])

# %%
def getField_cylinder(x, positions, M0, shape):
    B=magpy.getB(
        sources="Cylinder",
        position=x[:3],
        orientation=Rotation.align_vectors(x[3:], np.array([0, 0, 1]))[0],
        observers=positions,
        dimension=shape,
        polarization=(0, 0, M0),
    )
    return B

def cost_cylinder(x, B, positions, M0, shape):
    diff = getField_cylinder(x, positions, M0, shape) - B
    return np.sum((diff) ** 2)

def B_dipole(position, rotation, M0, shape):
    R = np.sqrt(np.sum(position**2, axis=1))
    B = (M0 * (shape[0]) ** 2 * shape[1] / (16)) * (
        (
            3
            * position
            / R[:, np.newaxis] ** 5
            * (eo.einsum(position, rotation, "sensor dim,  dim -> sensor"))[
                :, np.newaxis
            ]
        )
        - rotation[np.newaxis, :] / (R[:, np.newaxis] ** 3)
    )
    return B


def getField_dipole(x, positions, M0, shape):
    position = x[:3]
    axis = x[3:]
    return B_dipole(positions - position, axis, M0, shape)


def getField_dipole_fixed(x, positions, M0, shape):
    position = x[:3]
    axis = x[3:]
    return B_dipole(positions - position, axis, M0, shape)


def cost_dipole(x, B, positions, M0, shape):
    diff = getField_dipole(x, positions, M0, shape) - B
    return np.sum((diff) ** 2)


def minimize(x0, B, positions, M0, shape, *args):
    #print("Starting mimimization")
    b_args = (B, positions, M0, shape)
    cons = [{"type": "eq", "fun": lambda x: x[3] ** 2 + x[4] ** 2 + x[5] ** 2 - 1}]
    bounds = [(-100, 100), (-100, 100), (0, 100), (-1, 1), (-1, 1), (-1, 1)]
    res = sp.optimize.minimize(
        fun=cost_dipole, x0=x0, args=b_args, tol=1e-100, constraints=cons, bounds=bounds, options={'maxiter':100000}, *args
    ) 
    #print(f"Finished mimimization with shape {b_args[3]} at {res}")
    return res.x 

# Function to extract the timestamp part from the file path
def extract_timestamp(file_path):
    # Extract the filename from the file path (without the extension)
    filename = os.path.basename(file_path).replace('.npz', '')
    
    # Split the filename into date, time, and millisecond parts
    date_part = filename.split('-')[0]  # Extracting the 'YYYYMMDD' part
    time_part = filename.split('-')[1]  # Extracting the 'HHMMSS' part
    millisecond_part = filename.split('-')[2]  # Extracting the millisecond part
    
    # Combine date, time, and milliseconds into a full timestamp string
    full_datetime_str = f"{date_part} {time_part}.{millisecond_part}"
    
    # Create a datetime object
    full_datetime = datetime.strptime(full_datetime_str, "%Y%m%d %H%M%S.%f")
    
    return full_datetime

def importdata(folder):

    file_list = sorted(glob.glob(f'{folder}/*.npz'))
    #print(file_list)
    data = np.load(file_list[0])
    pos = data['pos'][0]
    B = [np.array(pos)]
    timestamps = []

    for x in range(len(file_list)):
        try:
            data = np.load(file_list[x])
        except:
            display(file_list[x])
        mags = data['mags']
        pos = data['pos'][0]
        mags = np.mean(mags, axis=0)
        
        B = np.append(B, [mags], axis=0)
        timestamps.append(extract_timestamp(file_list[x]))  
    B = np.delete(B, 0, axis=0)

    return B, timestamps, pos

def fitting(B, pos):
    locpred = [np.array([0,0,0])]
    anglepred = [np.array([0,0,0])]

    for x in range(len(B)):
        mags = B[x]
        #print(mags)
        x_res = minimize(x0, mags, pos, M0, shape)
        locpred = np.append(locpred, [x_res[0:3]], axis=0)
        #print(locpred)
        anglepred = np.append(anglepred, [x_res[3:6]], axis=0)

    locpred = np.delete(locpred, 0, axis=0)
    anglepred = np.delete(anglepred, 0, axis=0)
    

    return locpred, anglepred

def sensorplots(B, timestamps, sensor):
    mag = [np.array([0, 0, 0])]
    for x in range(len(B)):
        mag = np.append(mag, [B[x][sensor]], axis=0)
    mag = np.delete(mag, 0, axis=0)

    measuredbx = go.Scatter(x=timestamps, y=mag[:,0], mode='markers')
    layoutbx = go.Layout(title='b_x over time, sensor ' + str(sensor))
    figbx = go.Figure(data=[measuredbx], layout=layoutbx)
    figbx.update_yaxes(scaleanchor='y')
    figbx.update_layout(
        xaxis_title="Time",
        yaxis_title="b_x [mT]"
    )
    figbx.show()

    measuredby = go.Scatter(x=timestamps, y=mag[:,1], mode='markers')
    layoutby = go.Layout(title='b_y over time sensor ' + str(sensor))
    figby = go.Figure(data=[measuredby], layout=layoutby)
    figby.update_yaxes(scaleanchor='y')
    figby.update_layout(
        xaxis_title="Time",
        yaxis_title="b_y [mT]"
    )
    figby.show()

    measuredbz = go.Scatter(x=timestamps, y=mag[:,2], mode='markers')
    layoutbz = go.Layout(title='b_z over time sensor ' + str(sensor))
    figbz = go.Figure(data=[measuredbz], layout=layoutbz)
    figbz.update_yaxes(scaleanchor='y')
    figbz.update_layout(
        xaxis_title="Time",
        yaxis_title="b_z [mT]"
    )
    figbz.show()

# %% [markdown]
# import functions from MagneticSensorTracking
# graph bx, by, bz for all 16 sensors
# try averaging the sensors logs
# try restarting pi to see if time error is from restarts
# fix the mount

# %%
folder = os.path.join('..', './MLX10102024_D52N52_GK4')
B, timestamps, pos = importdata(folder)

# %%
sensorplots(B, timestamps, 8)

# %%
def moving_average_3d(arr, window_size=3):
    # Ensure input is 3D
    if arr.ndim != 3:
        raise ValueError("Input array must be 3D.")
    
    # Initialize smoothed array with zeros
    smoothed_arr = np.zeros_like(arr)
    
    # Apply moving average along the first dimension for each column in 2D slices
    for i in range(arr.shape[1]):
        for j in range(arr.shape[2]):
            kernel = np.ones(window_size) / window_size
            smoothed_slice = np.convolve(arr[:, i, j], kernel, mode='same')
            smoothed_arr[:, i, j] = smoothed_slice
            
    return smoothed_arr

def average_along_first_dim(arr, window_size=3):
    # Ensure input is 3D
    if arr.ndim != 3:
        raise ValueError("Input array must be 3D.")
    
    # Calculate the shape of the output array based on window size
    num_windows = arr.shape[0] // window_size
    averaged_arr = np.zeros((num_windows, arr.shape[1], arr.shape[2]))
    
    # Loop through and calculate the mean for each window
    for i in range(num_windows):
        start_idx = i * window_size
        end_idx = start_idx + window_size
        averaged_arr[i] = np.mean(arr[start_idx:end_idx], axis=0)
        
    return averaged_arr

test = average_along_first_dim(B, window_size=5)
print(len(test))
# Out:
# 1013

# %%
timestamps
# Define the incorrect and correct times
incorrect_time = pd.to_datetime("6:00:00").time()  # Incorrect time (6:01)
correct_time = pd.to_datetime("12:08:00").time()   # Correct time (2:24)

# Calculate the time difference
time_difference = timedelta(hours=correct_time.hour, minutes=correct_time.minute, seconds=correct_time.second) - \
                  timedelta(hours=incorrect_time.hour, minutes=incorrect_time.minute, seconds=incorrect_time.second)

# Apply the time difference to correct the list of incorrect timestamps
corrected_timestamps = [t + time_difference for t in timestamps]
corrected_timestamps

ave_timestamps = corrected_timestamps[4::5]
print(len(ave_timestamps))
# Out:
# 1013

# %%
locpred, anglepred = fitting(test, pos)
# Out:
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01360883263519332
#        x: [-2.753e+01  2.043e+01  3.451e+01 -1.133e-01  5.000e-01
#             8.586e-01]
#      nit: 146
#      jac: [ 2.794e-09  1.630e-09  2.561e-09 -1.490e-03  6.574e-03
#             1.129e-02]
#     nfev: 1172
#     njev: 143
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013635003423925512
#        x: [-2.755e+01  2.024e+01  3.459e+01 -1.143e-01  4.894e-01
#             8.645e-01]
#      nit: 128
#      jac: [ 2.328e-09  9.313e-10 -4.657e-10 -1.504e-03  6.441e-03
#             1.138e-02]
#     nfev: 1001
#     njev: 125
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0135329966957002
#        x: [-2.757e+01  2.037e+01  3.451e+01 -1.159e-01  4.975e-01
#             8.597e-01]
#      nit: 138
#      jac: [ 5.821e-10 -1.397e-09  9.313e-10 -1.505e-03  6.458e-03
#             1.116e-02]
#     nfev: 1139
#     njev: 135
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013533370264121106
#        x: [-2.764e+01  2.032e+01  3.451e+01 -1.193e-01  4.952e-01
#             8.606e-01]
#      nit: 154
#      jac: [ 2.328e-09  2.095e-09  6.985e-10 -1.567e-03  6.502e-03
#             1.130e-02]
#     nfev: 1270
#     njev: 152
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013546702887833158
#        x: [-2.748e+01  2.037e+01  3.455e+01 -1.095e-01  4.971e-01
#             8.608e-01]
#      nit: 132
#      jac: [ 1.164e-09  9.313e-10  3.492e-09 -1.422e-03  6.458e-03
#             1.118e-02]
#     nfev: 1068
#     njev: 129
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013743307473678652
#        x: [-2.774e+01  2.041e+01  3.442e+01 -1.260e-01  4.996e-01
#             8.570e-01]
#      nit: 125
#      jac: [ 3.027e-09 -2.328e-10 -2.328e-10 -1.651e-03  6.549e-03
#             1.123e-02]
#     nfev: 977
#     njev: 123
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01368619714241883
#        x: [-2.758e+01  2.041e+01  3.449e+01 -1.156e-01  4.982e-01
#             8.593e-01]
#      nit: 172
#      jac: [ 4.424e-09  2.095e-09  2.445e-09 -1.543e-03  6.649e-03
#             1.147e-02]
#     nfev: 1571
#     njev: 169
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013699849600617105
#        x: [-2.756e+01  2.042e+01  3.450e+01 -1.142e-01  5.004e-01
#             8.582e-01]
#      nit: 129
#      jac: [ 1.863e-09  1.164e-09  1.281e-09 -1.508e-03  6.611e-03
#             1.134e-02]
#     nfev: 989
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013541576950053756
#        x: [-2.750e+01  2.043e+01  3.451e+01 -1.118e-01  5.003e-01
#             8.586e-01]
#      nit: 134
#      jac: [ 8.149e-10  6.985e-10  4.540e-09 -1.472e-03  6.589e-03
#             1.131e-02]
#     nfev: 1082
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013639400450489936
#        x: [-2.755e+01  2.042e+01  3.450e+01 -1.138e-01  5.000e-01
#             8.585e-01]
#      nit: 129
#      jac: [ 3.027e-09  2.095e-09  4.657e-10 -1.512e-03  6.645e-03
#             1.141e-02]
#     nfev: 1024
#     njev: 127
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013575662549158731
#        x: [-2.756e+01  2.036e+01  3.452e+01 -1.159e-01  4.972e-01
#             8.599e-01]
#      nit: 139
#      jac: [ 5.588e-09  4.424e-09  3.609e-09 -1.537e-03  6.595e-03
#             1.141e-02]
#     nfev: 1197
#     njev: 136
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013468034406128877
#        x: [-2.750e+01  2.027e+01  3.461e+01 -1.119e-01  4.904e-01
#             8.643e-01]
#      nit: 146
#      jac: [ 3.492e-09  1.746e-09  3.492e-10 -1.464e-03  6.420e-03
#             1.132e-02]
#     nfev: 1107
#     njev: 144
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013510093659073824
#        x: [-2.764e+01  2.044e+01  3.445e+01 -1.211e-01  5.020e-01
#             8.563e-01]
#      nit: 130
#      jac: [ 3.027e-09  1.397e-09  1.863e-09 -1.561e-03  6.469e-03
#             1.103e-02]
#     nfev: 1092
#     njev: 127
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013405714014483178
#        x: [-2.750e+01  2.041e+01  3.455e+01 -1.125e-01  4.986e-01
#             8.595e-01]
#      nit: 184
#      jac: [ 2.328e-09  3.725e-09  2.794e-09 -1.489e-03  6.597e-03
#             1.137e-02]
#     nfev: 1762
#     njev: 181
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013857619929469817
#        x: [-2.761e+01  2.041e+01  3.448e+01 -1.189e-01  4.992e-01
#             8.583e-01]
#      nit: 125
#      jac: [ 1.746e-09  2.678e-09  3.609e-09 -1.600e-03  6.713e-03
#             1.154e-02]
#     nfev: 984
#     njev: 123
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01360828642550797
#        x: [-2.756e+01  2.034e+01  3.455e+01 -1.151e-01  4.953e-01
#             8.610e-01]
#      nit: 133
#      jac: [ 3.492e-09  3.027e-09  2.328e-09 -1.525e-03  6.562e-03
#             1.141e-02]
#     nfev: 1033
#     njev: 130
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013511973774407729
#        x: [-2.776e+01  2.051e+01  3.436e+01 -1.272e-01  5.069e-01
#             8.526e-01]
#      nit: 110
#      jac: [ 1.863e-09  1.513e-09  2.095e-09 -1.659e-03  6.613e-03
#             1.112e-02]
#     nfev: 870
#     njev: 108
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01351860984224231
#        x: [-2.776e+01  2.042e+01  3.441e+01 -1.280e-01  5.012e-01
#             8.558e-01]
#      nit: 173
#      jac: [ 2.794e-09  3.492e-09  1.513e-09 -1.674e-03  6.555e-03
#             1.119e-02]
#     nfev: 1597
#     njev: 170
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013679271739558803
#        x: [-2.746e+01  2.035e+01  3.459e+01 -1.089e-01  4.941e-01
#             8.625e-01]
#      nit: 150
#      jac: [ 1.397e-09  1.863e-09  6.985e-10 -1.446e-03  6.557e-03
#             1.145e-02]
#     nfev: 1276
#     njev: 147
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013524021509743047
#        x: [-2.765e+01  2.036e+01  3.449e+01 -1.216e-01  4.977e-01
#             8.588e-01]
#      nit: 145
#      jac: [ 5.821e-10  1.746e-09  1.397e-09 -1.597e-03  6.535e-03
#             1.128e-02]
#     nfev: 1218
#     njev: 142
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013437848301791266
#        x: [-2.758e+01  2.036e+01  3.452e+01 -1.169e-01  4.972e-01
#             8.597e-01]
#      nit: 137
#      jac: [ 3.027e-09  3.958e-09  1.863e-09 -1.525e-03  6.486e-03
#             1.122e-02]
#     nfev: 1061
#     njev: 134
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013440079063722432
#        x: [-2.745e+01  2.028e+01  3.463e+01 -1.064e-01  4.900e-01
#             8.652e-01]
#      nit: 125
#      jac: [ 6.985e-10  1.513e-09  1.746e-09 -1.391e-03  6.405e-03
#             1.131e-02]
#     nfev: 966
#     njev: 122
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013505920788935545
#        x: [-2.735e+01  2.034e+01  3.463e+01 -1.008e-01  4.941e-01
#             8.635e-01]
#      nit: 140
#      jac: [ 2.910e-09  1.397e-09  5.821e-10 -1.308e-03  6.408e-03
#             1.120e-02]
#     nfev: 1133
#     njev: 137
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01362065411393346
#        x: [-2.739e+01  2.013e+01  3.471e+01 -1.017e-01  4.814e-01
#             8.706e-01]
#      nit: 121
#      jac: [ 4.657e-10  1.513e-09  1.630e-09 -1.352e-03  6.400e-03
#             1.157e-02]
#     nfev: 966
#     njev: 119
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013558048100033634
#        x: [-2.746e+01  2.022e+01  3.463e+01 -1.070e-01  4.872e-01
#             8.667e-01]
#      nit: 141
#      jac: [ 2.561e-09 -4.657e-10  2.328e-09 -1.415e-03  6.442e-03
#             1.146e-02]
#     nfev: 1164
#     njev: 138
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013491637510999188
#        x: [-2.736e+01  2.020e+01  3.467e+01 -1.012e-01  4.862e-01
#             8.680e-01]
#      nit: 131
#      jac: [ 2.095e-09 -1.164e-10 -1.746e-09 -1.322e-03  6.348e-03
#             1.133e-02]
#     nfev: 1037
#     njev: 128
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013435622307534322
#        x: [-2.747e+01  2.008e+01  3.469e+01 -1.068e-01  4.806e-01
#             8.704e-01]
#      nit: 123
#      jac: [ 3.027e-09  3.492e-09  4.657e-09 -1.393e-03  6.268e-03
#             1.135e-02]
#     nfev: 958
#     njev: 120
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013596364543502444
#        x: [-2.748e+01  2.028e+01  3.458e+01 -1.096e-01  4.918e-01
#             8.638e-01]
#      nit: 133
#      jac: [ 2.561e-09  1.746e-09  1.048e-09 -1.437e-03  6.452e-03
#             1.133e-02]
#     nfev: 1047
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013563219861141073
#        x: [-2.757e+01  2.011e+01  3.463e+01 -1.148e-01  4.831e-01
#             8.680e-01]
#      nit: 151
#      jac: [ 8.149e-10  5.821e-10 -1.746e-09 -1.514e-03  6.370e-03
#             1.145e-02]
#     nfev: 1182
#     njev: 149
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013610840865666617
#        x: [-2.754e+01  2.015e+01  3.463e+01 -1.142e-01  4.842e-01
#             8.675e-01]
#      nit: 149
#      jac: [ 4.657e-10  6.985e-10 -1.164e-09 -1.501e-03  6.366e-03
#             1.140e-02]
#     nfev: 1323
#     njev: 146
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013444190789579813
#        x: [-2.754e+01  2.025e+01  3.457e+01 -1.134e-01  4.903e-01
#             8.641e-01]
#      nit: 143
#      jac: [ 2.561e-09  5.821e-10  2.328e-10 -1.469e-03  6.355e-03
#             1.120e-02]
#     nfev: 1135
#     njev: 141
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013552241243794016
#        x: [-2.756e+01  2.015e+01  3.462e+01 -1.157e-01  4.857e-01
#             8.665e-01]
#      nit: 147
#      jac: [ 3.027e-09  1.746e-09  5.821e-10 -1.518e-03  6.369e-03
#             1.136e-02]
#     nfev: 1156
#     njev: 145
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013776459043835527
#        x: [-2.741e+01  2.001e+01  3.477e+01 -1.055e-01  4.758e-01
#             8.732e-01]
#      nit: 120
#      jac: [ 1.630e-09  1.397e-09  1.281e-09 -1.407e-03  6.345e-03
#             1.164e-02]
#     nfev: 953
#     njev: 117
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01355291584985963
#        x: [-2.748e+01  2.001e+01  3.467e+01 -1.099e-01  4.813e-01
#             8.697e-01]
#      nit: 185
#      jac: [ 4.191e-09  2.328e-09  1.397e-09 -1.462e-03  6.402e-03
#             1.157e-02]
#     nfev: 1613
#     njev: 183
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013397604554945954
#        x: [-2.737e+01  1.964e+01  3.474e+01 -1.028e-01  4.741e-01
#             8.744e-01]
#      nit: 131
#      jac: [ 3.492e-09  2.561e-09  9.313e-10 -1.352e-03  6.234e-03
#             1.150e-02]
#     nfev: 1063
#     njev: 128
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013564647849423721
#        x: [-2.734e+01  1.975e+01  3.478e+01 -1.016e-01  4.662e-01
#             8.788e-01]
#      nit: 242
#      jac: [ 3.492e-09  4.307e-09  3.492e-09 -1.350e-03  6.196e-03
#             1.168e-02]
#     nfev: 2545
#     njev: 239
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013614325038245736
#        x: [-2.758e+01  2.044e+01  3.454e+01 -1.166e-01  4.831e-01
#             8.677e-01]
#      nit: 128
#      jac: [ 2.445e-09  1.863e-09  2.328e-09 -1.536e-03  6.360e-03
#             1.142e-02]
#     nfev: 1008
#     njev: 125
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013491920373489525
#        x: [-2.740e+01  2.100e+01  3.449e+01 -1.066e-01  4.911e-01
#             8.646e-01]
#      nit: 166
#      jac: [ 3.376e-09  3.958e-09  3.842e-09 -1.383e-03  6.373e-03
#             1.122e-02]
#     nfev: 1551
#     njev: 163
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013590221371253243
#        x: [-2.757e+01  2.144e+01  3.442e+01 -1.152e-01  4.961e-01
#             8.606e-01]
#      nit: 144
#      jac: [ 2.561e-09  2.561e-09  4.191e-09 -1.493e-03  6.426e-03
#             1.115e-02]
#     nfev: 1200
#     njev: 141
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013599095028620375
#        x: [-2.749e+01  2.185e+01  3.438e+01 -1.110e-01  5.027e-01
#             8.573e-01]
#      nit: 138
#      jac: [ 3.260e-09 -2.328e-09  1.164e-09 -1.423e-03  6.446e-03
#             1.099e-02]
#     nfev: 1080
#     njev: 136
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013680489340801502
#        x: [-2.754e+01  2.223e+01  3.442e+01 -1.127e-01  5.030e-01
#             8.569e-01]
#      nit: 129
#      jac: [ 3.492e-10  2.445e-09  3.143e-09 -1.440e-03  6.426e-03
#             1.095e-02]
#     nfev: 1027
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013499806990536064
#        x: [-2.782e+01  2.277e+01  3.415e+01 -1.304e-01  5.201e-01
#             8.441e-01]
#      nit: 153
#      jac: [ 2.678e-09  2.095e-09  2.212e-09 -1.657e-03  6.611e-03
#             1.073e-02]
#     nfev: 1209
#     njev: 151
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013816993297687291
#        x: [-2.751e+01  2.293e+01  3.432e+01 -1.123e-01  5.138e-01
#             8.505e-01]
#      nit: 208
#      jac: [ 4.540e-09  5.821e-10  3.260e-09 -1.450e-03  6.635e-03
#             1.098e-02]
#     nfev: 1757
#     njev: 206
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013797264432556505
#        x: [-2.754e+01  2.307e+01  3.429e+01 -1.125e-01  5.159e-01
#             8.492e-01]
#      nit: 133
#      jac: [ 2.445e-09  2.794e-09  1.397e-09 -1.448e-03  6.638e-03
#             1.093e-02]
#     nfev: 1083
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013694914635229302
#        x: [-2.779e+01  2.343e+01  3.407e+01 -1.276e-01  5.303e-01
#             8.381e-01]
#      nit: 184
#      jac: [ 4.075e-09  1.746e-09  2.095e-09 -1.603e-03  6.661e-03
#             1.053e-02]
#     nfev: 1736
#     njev: 182
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013618234148909978
#        x: [-2.756e+01  2.338e+01  3.428e+01 -1.128e-01  5.206e-01
#             8.463e-01]
#      nit: 119
#      jac: [ 1.164e-09  1.164e-09 -1.863e-09 -1.430e-03  6.596e-03
#             1.072e-02]
#     nfev: 949
#     njev: 116
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013636927217748344
#        x: [-2.780e+01  2.370e+01  3.409e+01 -1.289e-01  5.274e-01
#             8.398e-01]
#      nit: 144
#      jac: [ 2.910e-09  6.985e-10 -1.863e-09 -1.639e-03  6.707e-03
#             1.068e-02]
#     nfev: 1133
#     njev: 142
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01384334074601341
#        x: [-2.774e+01  2.402e+01  3.401e+01 -1.242e-01  5.354e-01
#             8.354e-01]
#      nit: 120
#      jac: [ 6.985e-10  4.657e-10  1.513e-09 -1.563e-03  6.741e-03
#             1.052e-02]
#     nfev: 929
#     njev: 117
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013474503073646704
#        x: [-2.765e+01  2.427e+01  3.406e+01 -1.190e-01  5.331e-01
#             8.377e-01]
#      nit: 142
#      jac: [ 1.630e-09  2.678e-09  1.281e-09 -1.480e-03  6.629e-03
#             1.042e-02]
#     nfev: 1171
#     njev: 139
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013747732691090501
#        x: [-2.772e+01  2.430e+01  3.414e+01 -1.223e-01  5.250e-01
#             8.423e-01]
#      nit: 214
#      jac: [ 3.609e-09  3.376e-09  1.979e-09 -1.561e-03  6.699e-03
#             1.075e-02]
#     nfev: 2011
#     njev: 212
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013908410847343622
#        x: [-2.799e+01  2.466e+01  3.383e+01 -1.410e-01  5.491e-01
#             8.238e-01]
#      nit: 142
#      jac: [ 4.657e-10  2.445e-09  3.958e-09 -1.773e-03  6.909e-03
#             1.036e-02]
#     nfev: 1141
#     njev: 139
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013813527689924616
#        x: [-2.793e+01  2.487e+01  3.372e+01 -1.375e-01  5.617e-01
#             8.158e-01]
#      nit: 134
#      jac: [ 4.657e-10  0.000e+00 -4.657e-10 -1.732e-03  7.077e-03
#             1.028e-02]
#     nfev: 1042
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01363745749087368
#        x: [-2.813e+01  2.494e+01  3.359e+01 -1.496e-01  5.666e-01
#             8.103e-01]
#      nit: 121
#      jac: [ 2.328e-10  6.985e-10  1.164e-09 -1.858e-03  7.038e-03
#             1.007e-02]
#     nfev: 945
#     njev: 118
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013727331005896742
#        x: [-2.785e+01  2.482e+01  3.381e+01 -1.323e-01  5.567e-01
#             8.201e-01]
#      nit: 158
#      jac: [ 3.725e-09  1.979e-09 -1.746e-09 -1.668e-03  7.023e-03
#             1.034e-02]
#     nfev: 1231
#     njev: 156
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013724763280112198
#        x: [-2.795e+01  2.490e+01  3.369e+01 -1.390e-01  5.625e-01
#             8.150e-01]
#      nit: 126
#      jac: [ 1.863e-09  4.191e-09  1.863e-09 -1.752e-03  7.091e-03
#             1.027e-02]
#     nfev: 993
#     njev: 123
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013961612241497185
#        x: [-2.790e+01  2.478e+01  3.379e+01 -1.357e-01  5.550e-01
#             8.207e-01]
#      nit: 142
#      jac: [ 2.445e-09  2.794e-09  3.492e-09 -1.715e-03  7.013e-03
#             1.037e-02]
#     nfev: 1203
#     njev: 139
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013827658469267565
#        x: [-2.772e+01  2.461e+01  3.397e+01 -1.224e-01  5.431e-01
#             8.307e-01]
#      nit: 134
#      jac: [ 2.328e-09 -6.985e-10 -6.985e-10 -1.537e-03  6.819e-03
#             1.043e-02]
#     nfev: 1079
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013578930456345966
#        x: [-2.794e+01  2.454e+01  3.393e+01 -1.365e-01  5.417e-01
#             8.294e-01]
#      nit: 134
#      jac: [ 3.609e-09  2.561e-09  2.678e-09 -1.700e-03  6.751e-03
#             1.033e-02]
#     nfev: 1059
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013628040356295307
#        x: [-2.801e+01  2.481e+01  3.372e+01 -1.402e-01  5.583e-01
#             8.177e-01]
#      nit: 178
#      jac: [ 3.492e-10  2.794e-09  2.328e-09 -1.764e-03  7.026e-03
#             1.029e-02]
#     nfev: 1527
#     njev: 176
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01377363664020383
#        x: [-2.794e+01  2.467e+01  3.384e+01 -1.380e-01  5.493e-01
#             8.242e-01]
#      nit: 139
#      jac: [ 3.492e-09  1.048e-09  3.027e-09 -1.727e-03  6.875e-03
#             1.032e-02]
#     nfev: 1153
#     njev: 136
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013754290121229605
#        x: [-2.765e+01  2.466e+01  3.397e+01 -1.196e-01  5.455e-01
#             8.295e-01]
#      nit: 157
#      jac: [-2.328e-10 -5.821e-10  0.000e+00 -1.508e-03  6.883e-03
#             1.047e-02]
#     nfev: 1207
#     njev: 155
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013879092668927933
#        x: [-2.758e+01  2.456e+01  3.405e+01 -1.136e-01  5.409e-01
#             8.334e-01]
#      nit: 132
#      jac: [ 1.630e-09  1.630e-09  1.863e-09 -1.439e-03  6.854e-03
#             1.056e-02]
#     nfev: 1025
#     njev: 129
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013805704682359761
#        x: [-2.776e+01  2.459e+01  3.388e+01 -1.217e-01  5.582e-01
#             8.208e-01]
#      nit: 132
#      jac: [ 3.143e-09  3.027e-09  1.397e-09 -1.525e-03  6.993e-03
#             1.028e-02]
#     nfev: 1091
#     njev: 130
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013555652612927599
#        x: [-2.773e+01  2.402e+01  3.410e+01 -1.191e-01  5.399e-01
#             8.332e-01]
#      nit: 118
#      jac: [-6.985e-10  0.000e+00 -1.164e-10 -1.478e-03  6.698e-03
#             1.034e-02]
#     nfev: 908
#     njev: 115
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013856803866031952
#        x: [-2.757e+01  2.366e+01  3.422e+01 -1.101e-01  5.354e-01
#             8.374e-01]
#      nit: 126
#      jac: [ 2.794e-09  3.260e-09  2.561e-09 -1.400e-03  6.807e-03
#             1.065e-02]
#     nfev: 992
#     njev: 123
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01356619326797779
#        x: [-2.761e+01  2.327e+01  3.423e+01 -1.132e-01  5.283e-01
#             8.415e-01]
#      nit: 144
#      jac: [-1.164e-09  3.492e-10  4.657e-10 -1.426e-03  6.652e-03
#             1.059e-02]
#     nfev: 1143
#     njev: 142
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013683881777130315
#        x: [-2.757e+01  2.306e+01  3.429e+01 -1.127e-01  5.217e-01
#             8.457e-01]
#      nit: 123
#      jac: [ 4.075e-09  3.492e-09  4.191e-09 -1.420e-03  6.574e-03
#             1.066e-02]
#     nfev: 947
#     njev: 120
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013592396722863387
#        x: [-2.793e+01  2.313e+01  3.413e+01 -1.337e-01  5.299e-01
#             8.375e-01]
#      nit: 129
#      jac: [ 2.561e-09  3.492e-09  1.863e-09 -1.674e-03  6.632e-03
#             1.048e-02]
#     nfev: 1028
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013665777571560143
#        x: [-2.772e+01  2.296e+01  3.417e+01 -1.197e-01  5.333e-01
#             8.374e-01]
#      nit: 142
#      jac: [ 6.286e-09  5.821e-10  3.260e-09 -1.532e-03  6.826e-03
#             1.072e-02]
#     nfev: 1217
#     njev: 139
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013593080735556536
#        x: [-2.780e+01  2.266e+01  3.432e+01 -1.253e-01  5.176e-01
#             8.464e-01]
#      nit: 170
#      jac: [ 3.958e-09  8.149e-10  2.794e-09 -1.589e-03  6.561e-03
#             1.073e-02]
#     nfev: 1392
#     njev: 168
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013622124181208154
#        x: [-2.755e+01  2.276e+01  3.431e+01 -1.098e-01  5.264e-01
#             8.431e-01]
#      nit: 130
#      jac: [ 4.540e-09  2.445e-09  2.910e-09 -1.406e-03  6.740e-03
#             1.079e-02]
#     nfev: 1048
#     njev: 128
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013630882539321848
#        x: [-2.754e+01  2.233e+01  3.441e+01 -1.098e-01  5.163e-01
#             8.494e-01]
#      nit: 157
#      jac: [ 2.561e-09  3.027e-09  9.313e-10 -1.410e-03  6.633e-03
#             1.091e-02]
#     nfev: 1313
#     njev: 155
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013595574720379266
#        x: [-2.753e+01  2.196e+01  3.450e+01 -1.084e-01  5.070e-01
#             8.551e-01]
#      nit: 156
#      jac: [ 1.164e-09  1.630e-09  3.725e-09 -1.396e-03  6.529e-03
#             1.101e-02]
#     nfev: 1386
#     njev: 154
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013611018064420367
#        x: [-2.762e+01  2.170e+01  3.442e+01 -1.151e-01  5.099e-01
#             8.525e-01]
#      nit: 159
#      jac: [ 1.630e-09  0.000e+00  3.492e-10 -1.489e-03  6.598e-03
#             1.103e-02]
#     nfev: 1467
#     njev: 156
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01351239254334591
#        x: [-2.753e+01  2.167e+01  3.445e+01 -1.096e-01  5.112e-01
#             8.524e-01]
#      nit: 219
#      jac: [-3.492e-10 -2.328e-10  2.794e-09 -1.418e-03  6.614e-03
#             1.103e-02]
#     nfev: 2155
#     njev: 216
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013662219683385615
#        x: [-2.776e+01  2.177e+01  3.431e+01 -1.247e-01  5.204e-01
#             8.447e-01]
#      nit: 167
#      jac: [ 4.657e-10  2.328e-10  0.000e+00 -1.614e-03  6.738e-03
#             1.094e-02]
#     nfev: 1328
#     njev: 165
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013797437087004216
#        x: [-2.777e+01  2.184e+01  3.426e+01 -1.271e-01  5.243e-01
#             8.420e-01]
#      nit: 131
#      jac: [ 1.048e-09  4.657e-10  1.397e-09 -1.640e-03  6.765e-03
#             1.086e-02]
#     nfev: 1006
#     njev: 128
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013863137333665435
#        x: [-2.759e+01  2.202e+01  3.423e+01 -1.141e-01  5.326e-01
#             8.386e-01]
#      nit: 120
#      jac: [ 1.979e-09  1.513e-09  1.979e-09 -1.496e-03  6.980e-03
#             1.099e-02]
#     nfev: 970
#     njev: 117
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013779340170936905
#        x: [-2.766e+01  2.183e+01  3.433e+01 -1.187e-01  5.218e-01
#             8.448e-01]
#      nit: 129
#      jac: [ 2.095e-09  1.397e-09  1.630e-09 -1.558e-03  6.846e-03
#             1.108e-02]
#     nfev: 1033
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013649885820388888
#        x: [-2.790e+01  2.183e+01  3.421e+01 -1.340e-01  5.244e-01
#             8.409e-01]
#      nit: 154
#      jac: [ 4.657e-10  2.910e-09  3.492e-10 -1.725e-03  6.751e-03
#             1.083e-02]
#     nfev: 1245
#     njev: 151
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01364659027911242
#        x: [-2.773e+01  2.182e+01  3.428e+01 -1.242e-01  5.232e-01
#             8.431e-01]
#      nit: 141
#      jac: [ 2.561e-09 -4.657e-10  9.313e-10 -1.603e-03  6.755e-03
#             1.088e-02]
#     nfev: 1140
#     njev: 138
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013539550703825072
#        x: [-2.769e+01  2.175e+01  3.437e+01 -1.219e-01  5.180e-01
#             8.466e-01]
#      nit: 133
#      jac: [ 3.027e-09 -6.985e-10  1.863e-09 -1.574e-03  6.685e-03
#             1.093e-02]
#     nfev: 1101
#     njev: 130
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013563092429264016
#        x: [-2.769e+01  2.192e+01  3.426e+01 -1.213e-01  5.274e-01
#             8.409e-01]
#      nit: 117
#      jac: [-1.164e-09  1.863e-09  3.027e-09 -1.574e-03  6.847e-03
#             1.092e-02]
#     nfev: 900
#     njev: 114
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013733413102126297
#        x: [-2.781e+01  2.169e+01  3.433e+01 -1.293e-01  5.168e-01
#             8.463e-01]
#      nit: 179
#      jac: [ 2.794e-09  3.376e-09  5.239e-09 -1.690e-03  6.753e-03
#             1.106e-02]
#     nfev: 1639
#     njev: 176
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01360663263607454
#        x: [-2.785e+01  2.171e+01  3.430e+01 -1.312e-01  5.179e-01
#             8.453e-01]
#      nit: 128
#      jac: [ 6.985e-10  9.313e-10  1.513e-09 -1.682e-03  6.641e-03
#             1.084e-02]
#     nfev: 988
#     njev: 125
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013577330922191096
#        x: [-2.770e+01  2.184e+01  3.430e+01 -1.220e-01  5.233e-01
#             8.433e-01]
#      nit: 131
#      jac: [ 4.540e-09 -3.260e-09 -1.281e-09 -1.573e-03  6.745e-03
#             1.087e-02]
#     nfev: 1027
#     njev: 128
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013722238589447636
#        x: [-2.768e+01  2.167e+01  3.442e+01 -1.212e-01  5.140e-01
#             8.492e-01]
#      nit: 121
#      jac: [ 3.260e-09  1.746e-09  1.048e-09 -1.577e-03  6.687e-03
#             1.105e-02]
#     nfev: 945
#     njev: 118
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013593959267248707
#        x: [-2.775e+01  2.166e+01  3.437e+01 -1.256e-01  5.126e-01
#             8.494e-01]
#      nit: 166
#      jac: [ 2.910e-09  1.513e-09  2.445e-09 -1.633e-03  6.664e-03
#             1.104e-02]
#     nfev: 1548
#     njev: 163
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013628019247881224
#        x: [-2.774e+01  2.177e+01  3.432e+01 -1.246e-01  5.191e-01
#             8.456e-01]
#      nit: 138
#      jac: [ 2.445e-09  3.143e-09  1.164e-09 -1.612e-03  6.718e-03
#             1.094e-02]
#     nfev: 1117
#     njev: 135
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013596457652593433
#        x: [-2.777e+01  2.184e+01  3.426e+01 -1.256e-01  5.244e-01
#             8.421e-01]
#      nit: 147
#      jac: [ 1.164e-09  1.863e-09  1.863e-09 -1.625e-03  6.787e-03
#             1.090e-02]
#     nfev: 1180
#     njev: 144
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013569629106172687
#        x: [-2.769e+01  2.173e+01  3.436e+01 -1.220e-01  5.172e-01
#             8.471e-01]
#      nit: 128
#      jac: [ 2.794e-09  1.979e-09  1.746e-09 -1.581e-03  6.705e-03
#             1.098e-02]
#     nfev: 1012
#     njev: 125
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013472976060344167
#        x: [-2.774e+01  2.181e+01  3.429e+01 -1.251e-01  5.223e-01
#             8.435e-01]
#      nit: 125
#      jac: [ 2.910e-09  2.678e-09  2.212e-09 -1.591e-03  6.643e-03
#             1.073e-02]
#     nfev: 985
#     njev: 122
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013707604996053578
#        x: [-2.777e+01  2.185e+01  3.425e+01 -1.270e-01  5.248e-01
#             8.417e-01]
#      nit: 135
#      jac: [ 9.313e-10  6.985e-10  2.328e-09 -1.631e-03  6.737e-03
#             1.081e-02]
#     nfev: 1072
#     njev: 132
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013769815461784546
#        x: [-2.770e+01  2.187e+01  3.428e+01 -1.216e-01  5.257e-01
#             8.419e-01]
#      nit: 270
#      jac: [ 3.027e-09  3.958e-09  1.164e-09 -1.576e-03  6.817e-03
#             1.092e-02]
#     nfev: 3072
#     njev: 268
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013708797779404687
#        x: [-2.766e+01  2.179e+01  3.434e+01 -1.190e-01  5.207e-01
#             8.454e-01]
#      nit: 160
#      jac: [ 3.842e-09  8.149e-10  2.445e-09 -1.534e-03  6.712e-03
#             1.090e-02]
#     nfev: 1272
#     njev: 158
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013445027740849587
#        x: [-2.754e+01  2.171e+01  3.443e+01 -1.089e-01  5.128e-01
#             8.515e-01]
#      nit: 132
#      jac: [-1.164e-10  6.985e-10  3.260e-09 -1.393e-03  6.555e-03
#             1.088e-02]
#     nfev: 1032
#     njev: 129
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013646161756182783
#        x: [-2.752e+01  2.184e+01  3.434e+01 -1.087e-01  5.214e-01
#             8.464e-01]
#      nit: 146
#      jac: [ 3.027e-09  1.397e-09  2.561e-09 -1.400e-03  6.716e-03
#             1.090e-02]
#     nfev: 1308
#     njev: 143
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013751609356460828
#        x: [-2.770e+01  2.167e+01  3.437e+01 -1.207e-01  5.132e-01
#             8.497e-01]
#      nit: 157
#      jac: [ 4.540e-09  3.260e-09  3.027e-09 -1.558e-03  6.621e-03
#             1.096e-02]
#     nfev: 1463
#     njev: 154
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013698675947139262
#        x: [-2.751e+01  2.156e+01  3.452e+01 -1.082e-01  5.050e-01
#             8.563e-01]
#      nit: 129
#      jac: [ 1.979e-09  1.979e-09  2.678e-09 -1.401e-03  6.537e-03
#             1.108e-02]
#     nfev: 1015
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013639302361183343
#        x: [-2.751e+01  2.126e+01  3.458e+01 -1.084e-01  4.972e-01
#             8.608e-01]
#      nit: 144
#      jac: [ 3.958e-09  6.985e-10  6.985e-10 -1.420e-03  6.511e-03
#             1.127e-02]
#     nfev: 1150
#     njev: 141
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01354023013065169
#        x: [-2.751e+01  2.099e+01  3.457e+01 -1.072e-01  4.969e-01
#             8.612e-01]
#      nit: 178
#      jac: [ 1.863e-09  6.985e-10  1.979e-09 -1.385e-03  6.423e-03
#             1.113e-02]
#     nfev: 1493
#     njev: 176
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013601944022127239
#        x: [-2.750e+01  2.069e+01  3.457e+01 -1.080e-01  4.981e-01
#             8.604e-01]
#      nit: 129
#      jac: [ 1.048e-09  2.910e-09  2.328e-09 -1.397e-03  6.443e-03
#             1.113e-02]
#     nfev: 996
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013451758542389058
#        x: [-2.746e+01  2.040e+01  3.464e+01 -1.058e-01  4.901e-01
#             8.652e-01]
#      nit: 142
#      jac: [ 2.445e-09  1.630e-09  1.048e-09 -1.372e-03  6.356e-03
#             1.122e-02]
#     nfev: 1159
#     njev: 140
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013555490471813291
#        x: [-2.764e+01  2.031e+01  3.458e+01 -1.173e-01  4.903e-01
#             8.636e-01]
#      nit: 144
#      jac: [ 1.281e-09  3.492e-09  4.075e-09 -1.522e-03  6.363e-03
#             1.121e-02]
#     nfev: 1129
#     njev: 142
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013718808325276178
#        x: [-2.766e+01  2.014e+01  3.462e+01 -1.176e-01  4.838e-01
#             8.672e-01]
#      nit: 199
#      jac: [ 3.260e-09 -5.821e-10  3.376e-09 -1.534e-03  6.308e-03
#             1.131e-02]
#     nfev: 1878
#     njev: 197
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0137099923721865
#        x: [-2.749e+01  1.997e+01  3.476e+01 -1.083e-01  4.761e-01
#             8.727e-01]
#      nit: 131
#      jac: [ 2.678e-09  3.609e-09  1.048e-09 -1.420e-03  6.242e-03
#             1.144e-02]
#     nfev: 1060
#     njev: 128
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0133056757362233
#        x: [-2.754e+01  2.019e+01  3.464e+01 -1.124e-01  4.892e-01
#             8.649e-01]
#      nit: 128
#      jac: [ 1.863e-09  2.561e-09  2.328e-09 -1.464e-03  6.369e-03
#             1.126e-02]
#     nfev: 1051
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01367962593744657
#        x: [-2.757e+01  2.048e+01  3.447e+01 -1.144e-01  5.075e-01
#             8.540e-01]
#      nit: 138
#      jac: [ 9.313e-10  1.979e-09  1.863e-09 -1.517e-03  6.731e-03
#             1.133e-02]
#     nfev: 1080
#     njev: 135
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01344400573813649
#        x: [-2.766e+01  2.022e+01  3.457e+01 -1.178e-01  4.909e-01
#             8.632e-01]
#      nit: 136
#      jac: [ 2.445e-09  5.821e-10  1.979e-09 -1.535e-03  6.395e-03
#             1.125e-02]
#     nfev: 1089
#     njev: 134
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013587523605886088
#        x: [-2.760e+01  2.016e+01  3.463e+01 -1.159e-01  4.874e-01
#             8.654e-01]
#      nit: 137
#      jac: [ 4.191e-09  2.328e-10  2.212e-09 -1.535e-03  6.454e-03
#             1.146e-02]
#     nfev: 1087
#     njev: 135
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013670800891798243
#        x: [-2.770e+01  2.038e+01  3.445e+01 -1.227e-01  5.018e-01
#             8.562e-01]
#      nit: 141
#      jac: [ 2.328e-10  2.095e-09 -1.630e-09 -1.608e-03  6.574e-03
#             1.122e-02]
#     nfev: 1187
#     njev: 138
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01333580262536755
#        x: [-2.746e+01  2.021e+01  3.465e+01 -1.071e-01  4.900e-01
#             8.651e-01]
#      nit: 128
#      jac: [ 2.794e-09  3.609e-09  4.657e-10 -1.395e-03  6.380e-03
#             1.126e-02]
#     nfev: 1012
#     njev: 125
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013594941888711198
#        x: [-2.746e+01  2.010e+01  3.472e+01 -1.052e-01  4.823e-01
#             8.697e-01]
#      nit: 216
#      jac: [ 3.260e-09  3.143e-09  4.191e-09 -1.376e-03  6.307e-03
#             1.137e-02]
#     nfev: 2140
#     njev: 214
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01350713985079216
#        x: [-2.748e+01  2.027e+01  3.460e+01 -1.071e-01  4.936e-01
#             8.631e-01]
#      nit: 133
#      jac: [ 3.492e-09  9.313e-10  4.657e-10 -1.410e-03  6.494e-03
#             1.136e-02]
#     nfev: 1062
#     njev: 131
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013717434060811558
#        x: [-2.747e+01  1.982e+01  3.476e+01 -1.052e-01  4.754e-01
#             8.735e-01]
#      nit: 121
#      jac: [ 1.513e-09  1.979e-09  1.397e-09 -1.381e-03  6.244e-03
#             1.147e-02]
#     nfev: 966
#     njev: 119
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01334083901508082
#        x: [-2.737e+01  1.956e+01  3.471e+01 -1.005e-01  4.821e-01
#             8.703e-01]
#      nit: 255
#      jac: [ 5.006e-09  2.678e-09  3.376e-09 -1.339e-03  6.419e-03
#             1.159e-02]
#     nfev: 2575
#     njev: 253
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013528422105170204
#        x: [-2.730e+01  1.894e+01  3.486e+01 -9.642e-02  4.662e-01
#             8.794e-01]
#      nit: 149
#      jac: [ 1.746e-09  3.027e-09  3.492e-09 -1.279e-03  6.182e-03
#             1.166e-02]
#     nfev: 1281
#     njev: 147
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013613519445296325
#        x: [-2.727e+01  1.852e+01  3.490e+01 -9.549e-02  4.612e-01
#             8.821e-01]
#      nit: 129
#      jac: [ 2.910e-09  2.095e-09 -1.164e-10 -1.292e-03  6.238e-03
#             1.193e-02]
#     nfev: 1008
#     njev: 126
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013343367110185047
#        x: [-2.731e+01  1.836e+01  3.482e+01 -9.817e-02  4.680e-01
#             8.783e-01]
#      nit: 132
#      jac: [ 3.609e-09  3.492e-09  3.958e-09 -1.326e-03  6.320e-03
#             1.186e-02]
#     nfev: 1086
#     njev: 129
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013811530225970599
#        x: [-2.725e+01  1.780e+01  3.498e+01 -9.581e-02  4.512e-01
#             8.873e-01]
#      nit: 174
#      jac: [ 3.958e-09  0.000e+00 -2.328e-09 -1.290e-03  6.078e-03
#             1.195e-02]
#     nfev: 1581
#     njev: 172
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013523304830560096
#        x: [-2.721e+01  1.754e+01  3.500e+01 -9.357e-02  4.484e-01
#             8.889e-01]
#      nit: 167
#      jac: [ 5.704e-09  4.424e-09  2.328e-09 -1.252e-03  5.998e-03
#             1.189e-02]
#     nfev: 1510
#     njev: 165
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013368100171926255
#        x: [-2.736e+01  1.741e+01  3.493e+01 -1.017e-01  4.512e-01
#             8.866e-01]
#      nit: 182
#      jac: [ 9.313e-10  1.281e-09  1.630e-09 -1.374e-03  6.100e-03
#             1.199e-02]
#     nfev: 1683
#     njev: 179
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013446259937528938
#        x: [-2.724e+01  1.755e+01  3.490e+01 -9.484e-02  4.597e-01
#             8.830e-01]
#      nit: 142
#      jac: [ 2.328e-09  4.773e-09  6.985e-10 -1.269e-03  6.152e-03
#             1.182e-02]
#     nfev: 1124
#     njev: 139
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01350355903268211
#        x: [-2.747e+01  1.760e+01  3.479e+01 -1.107e-01  4.646e-01
#             8.786e-01]
#      nit: 132
#      jac: [ 1.048e-09  2.445e-09  1.746e-09 -1.495e-03  6.275e-03
#             1.187e-02]
#     nfev: 1064
#     njev: 129
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013557786272388595
#        x: [-2.746e+01  1.748e+01  3.485e+01 -1.103e-01  4.570e-01
#             8.826e-01]
#      nit: 137
#      jac: [ 5.704e-09  2.678e-09  5.472e-09 -1.500e-03  6.210e-03
#             1.199e-02]
#     nfev: 1147
#     njev: 135
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013512501707551576
#        x: [-2.743e+01  1.751e+01  3.486e+01 -1.082e-01  4.581e-01
#             8.823e-01]
#      nit: 122
#      jac: [ 6.985e-10  2.328e-09  2.445e-09 -1.452e-03  6.148e-03
#             1.184e-02]
#     nfev: 933
#     njev: 119
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.013497902699307026
#        x: [-2.754e+01  1.750e+01  3.481e+01 -1.148e-01  4.591e-01
#             8.809e-01]
#      nit: 132
#      jac: [ 2.445e-09 -3.492e-10  1.513e-09 -1.532e-03  6.129e-03
#             1.176e-02]
#     nfev: 1008
#     njev: 129
# ...
#      nit: 287
#      jac: [ 0.000e+00  0.000e+00  5.683e-07 -2.178e-04  1.870e-04
#            -1.605e-04]
#     nfev: 2379
#     njev: 286
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.012051389710046052
#        x: [ 5.405e+01 -9.051e+01  1.187e-22  6.819e-01 -5.501e-01
#             4.821e-01]
#      nit: 334
#      jac: [-1.164e-10  0.000e+00  6.509e-07 -2.262e-04  1.824e-04
#            -1.599e-04]
#     nfev: 2984
#     njev: 333
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011985260913417475
#        x: [ 5.666e+01 -8.867e+01  1.200e-17  7.221e-01 -4.966e-01
#             4.817e-01]
#      nit: 386
#      jac: [ 2.328e-10  0.000e+00  6.357e-07 -2.361e-04  1.624e-04
#            -1.575e-04]
#     nfev: 3744
#     njev: 385
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011862502418265948
#        x: [ 5.930e+01 -8.358e+01  8.505e+00  6.958e-01 -3.172e-01
#             6.444e-01]
#      nit: 115
#      jac: [ 1.979e-08 -2.107e-08  2.631e-07 -2.304e-04  1.049e-04
#            -2.148e-04]
#     nfev: 878
#     njev: 115
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010752149528002308
#        x: [ 3.920e+01  4.415e+01  6.909e+01 -7.692e-01  5.455e-01
#            -3.329e-01]
#      nit: 247
#      jac: [-2.328e-10 -1.164e-10 -2.328e-10 -8.303e-05  5.889e-05
#            -3.593e-05]
#     nfev: 2002
#     njev: 247
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010685452695176218
#        x: [ 4.527e+01  3.719e+01  6.251e+01 -7.188e-01  6.936e-01
#            -4.725e-02]
#      nit: 386
#      jac: [ 1.164e-10  1.164e-10  1.164e-10 -3.145e-05  3.034e-05
#            -2.067e-06]
#     nfev: 4343
#     njev: 386
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010713388753351177
#        x: [ 4.970e+01  3.599e+01  5.993e+01 -6.675e-01  7.442e-01
#             2.370e-02]
#      nit: 248
#      jac: [ 1.164e-10  1.164e-10  0.000e+00 -2.366e-05  2.638e-05
#             8.389e-07]
#     nfev: 2223
#     njev: 248
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010996936564085074
#        x: [ 4.960e+01  3.681e+01  6.153e+01 -6.590e-01  7.521e-01
#            -4.831e-03]
#      nit: 220
#      jac: [ 1.164e-10  1.164e-10  2.328e-10 -4.077e-05  4.653e-05
#            -2.984e-07]
#     nfev: 1763
#     njev: 220
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010715096791234873
#        x: [ 4.668e+01  3.698e+01  6.596e+01 -6.287e-01  7.709e-01
#            -1.020e-01]
#      nit: 221
#      jac: [ 1.164e-10  2.328e-10  3.492e-10 -4.154e-05  5.094e-05
#            -6.740e-06]
#     nfev: 1749
#     njev: 221
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010776929459064164
#        x: [ 4.089e+01  3.699e+01  7.163e+01 -6.082e-01  7.583e-01
#            -2.345e-01]
#      nit: 185
#      jac: [ 1.164e-10  1.164e-10  1.164e-10 -6.734e-05  8.395e-05
#            -2.596e-05]
#     nfev: 1494
#     njev: 185
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010723577537605581
#        x: [ 3.510e+01  3.967e+01  7.481e+01 -6.039e-01  6.921e-01
#            -3.955e-01]
#      nit: 228
#      jac: [ 1.164e-10  2.328e-10  2.328e-10 -7.265e-05  8.326e-05
#            -4.758e-05]
#     nfev: 1894
#     njev: 228
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010472184399748879
#        x: [ 3.470e+01  4.069e+01  7.441e+01 -6.587e-01  6.153e-01
#            -4.330e-01]
#      nit: 210
#      jac: [ 2.328e-10  0.000e+00  0.000e+00 -7.746e-05  7.236e-05
#            -5.091e-05]
#     nfev: 1558
#     njev: 210
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011908085605770273
#        x: [ 4.663e+01 -9.438e+01  2.511e-23  5.854e-01 -5.803e-01
#             5.663e-01]
#      nit: 289
#      jac: [ 2.328e-10  2.328e-10  6.766e-07 -1.889e-04  1.872e-04
#            -1.827e-04]
#     nfev: 2536
#     njev: 288
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01184492125323363
#        x: [ 5.308e+01 -8.659e+01  9.121e+00  6.317e-01 -3.252e-01
#             7.037e-01]
#      nit: 129
#      jac: [ 7.218e-09 -8.149e-09  9.744e-08 -2.159e-04  1.111e-04
#            -2.411e-04]
#     nfev: 1049
#     njev: 129
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01182053960969014
#        x: [ 5.216e+01 -8.710e+01  8.891e+00  6.133e-01 -3.462e-01
#             7.100e-01]
#      nit: 184
#      jac: [ 2.328e-10  1.614e-07  3.220e-07 -2.068e-04  1.171e-04
#            -2.393e-04]
#     nfev: 1382
#     njev: 184
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011902295984946968
#        x: [ 5.085e+01 -8.826e+01  9.230e+00  5.974e-01 -3.669e-01
#             7.130e-01]
#      nit: 124
#      jac: [ 6.985e-09 -7.218e-09  9.430e-08 -2.014e-04  1.237e-04
#            -2.409e-04]
#     nfev: 952
#     njev: 124
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011949752328977882
#        x: [ 5.311e+01 -8.702e+01  9.042e+00  6.383e-01 -3.279e-01
#             6.964e-01]
#      nit: 245
#      jac: [-1.164e-09  2.212e-09 -1.455e-08 -2.142e-04  1.100e-04
#            -2.337e-04]
#     nfev: 2308
#     njev: 245
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01195888134755126
#        x: [ 5.430e+01 -8.586e+01  9.014e+00  6.409e-01 -3.113e-01
#             7.017e-01]
#      nit: 556
#      jac: [-8.848e-09  3.201e-08  9.732e-08 -2.209e-04  1.074e-04
#            -2.418e-04]
#     nfev: 4635
#     njev: 556
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011917701584904388
#        x: [ 4.533e+01 -9.475e+01  3.887e-20  5.670e-01 -5.931e-01
#             5.715e-01]
#      nit: 227
#      jac: [ 3.492e-10  4.657e-10  7.630e-07 -1.786e-04  1.868e-04
#            -1.800e-04]
#     nfev: 1791
#     njev: 227
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011990421447208419
#        x: [ 4.780e+01 -9.359e+01  7.614e-16  6.040e-01 -5.573e-01
#             5.697e-01]
#      nit: 258
#      jac: [ 0.000e+00  1.164e-10  7.796e-07 -1.932e-04  1.783e-04
#            -1.823e-04]
#     nfev: 1941
#     njev: 258
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011896715238505063
#        x: [ 5.453e+01 -8.526e+01  9.147e+00  6.454e-01 -2.951e-01
#             7.045e-01]
#      nit: 124
#      jac: [ 2.212e-09 -1.979e-09  2.759e-08 -2.209e-04  1.010e-04
#            -2.412e-04]
#     nfev: 1008
#     njev: 124
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01195335531422552
#        x: [ 4.720e+01 -9.378e+01  2.137e-17  5.959e-01 -5.636e-01
#             5.721e-01]
#      nit: 275
#      jac: [ 0.000e+00 -1.164e-10  7.165e-07 -1.933e-04  1.828e-04
#            -1.856e-04]
#     nfev: 2179
#     njev: 275
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.012157935068230142
#        x: [ 5.365e+01 -8.675e+01  9.073e+00  6.404e-01 -3.230e-01
#             6.969e-01]
#      nit: 148
#      jac: [ 1.315e-08 -1.746e-08  1.094e-07 -2.193e-04  1.108e-04
#            -2.388e-04]
#     nfev: 1172
#     njev: 148
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011978096121295797
#        x: [ 5.475e+01 -8.862e+01  1.051e-14  7.222e-01 -4.196e-01
#             5.498e-01]
#      nit: 263
#      jac: [ 1.012e-07  1.993e-07  4.385e-07 -2.293e-04  1.330e-04
#            -1.746e-04]
#     nfev: 2110
#     njev: 263
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010734657699982702
#        x: [ 3.912e+01  4.180e+01  6.934e+01 -7.416e-01  5.892e-01
#            -3.208e-01]
#      nit: 227
#      jac: [ 2.328e-10  2.328e-10  2.328e-10 -7.849e-05  6.235e-05
#            -3.395e-05]
#     nfev: 1707
#     njev: 227
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010938016675593045
#        x: [ 4.574e+01  3.669e+01  6.150e+01 -6.994e-01  7.146e-01
#            -1.159e-02]
#      nit: 244
#      jac: [ 0.000e+00  0.000e+00  0.000e+00 -3.196e-05  3.266e-05
#            -5.285e-07]
#     nfev: 2216
#     njev: 244
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.0109773509516303
#        x: [ 4.452e+01  3.638e+01  6.108e+01 -7.148e-01  6.993e-01
#            -1.043e-02]
#      nit: 190
#      jac: [ 1.164e-10  1.164e-10  1.164e-10 -1.581e-05  1.547e-05
#            -2.306e-07]
#     nfev: 1456
#     njev: 190
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010897783008896007
#        x: [ 4.392e+01  3.679e+01  6.019e+01 -7.291e-01  6.842e-01
#            -1.734e-02]
#      nit: 201
#      jac: [ 1.164e-10  2.328e-10  1.164e-10  1.047e-05 -9.826e-06
#             2.501e-07]
#     nfev: 1536
#     njev: 201
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010890962237077504
#        x: [ 4.498e+01  3.823e+01  5.756e+01 -7.406e-01  6.717e-01
#            -1.619e-02]
#      nit: 239
#      jac: [ 2.328e-10  2.328e-10  2.328e-10  3.307e-05 -2.999e-05
#             7.239e-07]
#     nfev: 2067
#     njev: 239
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010777653807260451
#        x: [ 4.481e+01  3.754e+01  5.759e+01 -7.414e-01  6.709e-01
#            -1.433e-02]
#      nit: 181
#      jac: [ 1.164e-10  0.000e+00  2.328e-10  2.600e-05 -2.352e-05
#             5.027e-07]
#     nfev: 1402
#     njev: 181
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01091400059440398
#        x: [ 4.006e+01  3.761e+01  6.078e+01 -7.504e-01  6.540e-01
#            -9.595e-02]
#      nit: 210
#      jac: [ 4.657e-10  2.328e-10  1.164e-10  2.225e-05 -1.939e-05
#             2.845e-06]
#     nfev: 1559
#     njev: 210
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.011080667903357821
#        x: [ 3.959e+01  3.731e+01  6.119e+01 -7.473e-01  6.557e-01
#            -1.076e-01]
#      nit: 208
#      jac: [ 2.328e-10  2.328e-10  3.492e-10  2.704e-05 -2.372e-05
#             3.893e-06]
#     nfev: 1614
#     njev: 208
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010845485625065392
#        x: [ 3.839e+01  3.767e+01  6.173e+01 -7.494e-01  6.487e-01
#            -1.322e-01]
#      nit: 204
#      jac: [ 2.328e-10  1.164e-10  1.164e-10  3.994e-05 -3.457e-05
#             7.048e-06]
#     nfev: 1553
#     njev: 204
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010756277552823788
#        x: [ 3.985e+01  3.591e+01  6.166e+01 -7.342e-01  6.723e-01
#            -9.493e-02]
#      nit: 207
#      jac: [ 2.328e-10  1.164e-10  0.000e+00  1.658e-05 -1.518e-05
#             2.143e-06]
#     nfev: 1724
#     njev: 207
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010877124262845674
#        x: [ 3.718e+01  3.559e+01  6.365e+01 -7.340e-01  6.663e-01
#            -1.317e-01]
#      nit: 206
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  2.076e-05 -1.885e-05
#             3.726e-06]
#     nfev: 1536
#     njev: 206
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010947524166279338
#        x: [ 3.895e+01  3.640e+01  6.198e+01 -7.355e-01  6.672e-01
#            -1.178e-01]
#      nit: 254
#      jac: [ 1.164e-10  1.164e-10  1.164e-10  2.481e-05 -2.251e-05
#             3.975e-06]
#     nfev: 2356
#     njev: 254
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010934505693331723
#        x: [ 3.820e+01  3.648e+01  6.257e+01 -7.378e-01  6.630e-01
#            -1.268e-01]
#      nit: 186
#      jac: [ 2.328e-10  0.000e+00  0.000e+00  1.619e-05 -1.455e-05
#             2.783e-06]
#     nfev: 1396
#     njev: 186
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010616690122496471
#        x: [ 3.644e+01  3.426e+01  6.456e+01 -7.250e-01  6.762e-01
#            -1.308e-01]
#      nit: 197
#      jac: [ 1.164e-10  1.164e-10  2.328e-10  1.909e-05 -1.781e-05
#             3.445e-06]
#     nfev: 1515
#     njev: 197
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01093237608442119
#        x: [ 3.865e+01  3.778e+01  6.151e+01 -7.495e-01  6.492e-01
#            -1.297e-01]
#      nit: 206
#      jac: [ 1.164e-10  2.328e-10  2.328e-10  3.272e-05 -2.834e-05
#             5.662e-06]
#     nfev: 1638
#     njev: 206
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010816151566094615
#        x: [ 3.999e+01  3.631e+01  6.140e+01 -7.336e-01  6.722e-01
#            -9.995e-02]
#      nit: 181
#      jac: [ 0.000e+00  2.328e-10  0.000e+00  3.229e-05 -2.959e-05
#             4.399e-06]
#     nfev: 1352
#     njev: 181
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.010799451722822923
#        x: [ 4.052e+01  3.595e+01  6.117e+01 -7.280e-01  6.792e-01
#            -9.273e-02]
#      nit: 208
#      jac: [ 3.492e-10  2.328e-10  3.492e-10  3.529e-05 -3.293e-05
#             4.495e-06]
#     nfev: 1621
#     njev: 208
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01103861201614863
#        x: [ 4.011e+01  3.663e+01  6.118e+01 -7.367e-01  6.686e-01
#            -1.012e-01]
#      nit: 204
#      jac: [ 3.492e-10  2.328e-10  1.164e-10  2.612e-05 -2.370e-05
#             3.589e-06]
#     nfev: 1591
#     njev: 204
# Finished mimimization with shape [7.9375, 3.175] at  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.01087378531006624
#        x: [ 3.964e+01  3.652e+01  6.164e+01 -7.333e-01  6.712e-01
#            -1.083e-01]
#      nit: 198
#      jac: [ 1.164e-10  0.000e+00  1.164e-10  2.615e-05 -2.394e-05
#             3.863e-06]
#     nfev: 1508
#     njev: 198

# %% [markdown]
# Lookup what algorithm the minimization is using: lookup what status 9 is. Figure out what algorithm the raspberry pi is using.
# Print new mount, measure on friday.
# redo plots with no averaging
# Look into how kinect stuff used software for tracking, can we apply to magnet stuff?

# %%
# Specify the Excel file name (replace with your actual file name)
file = 'Shift_data_10102024gk.txt'

# Create the full file path
file_path = os.path.join('..', file)

# Read the Excel file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=',', na_values="        NaN")

df.dropna(inplace=True)
df[['X', 'Y', 'Z', 'Displacement [mm]']] = df[['X', 'Y', 'Z', 'Displacement [mm]']].apply(pd.to_numeric,errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%dT%H:%M:%S.%f')
df['datetime'] = df.loc[0:,'Time'].dt.time


#print(df)
hdmm_time = df['Time']
hdmm_disp = df.loc[0:,'Displacement [mm]']
hdmm_x = df.loc[0:, 'X']
hdmm_y = df.loc[0:, 'Y']
hdmm_z = df.loc[0:, 'Z']
#print(hdmm_time)

# %%
rel_loc_predx = [x - locpred[0,0] for x in locpred[:,0]]
rel_loc_predy = [x - locpred[0,1] for x in locpred[:,1]]
rel_loc_predz = [x - locpred[0,2] for x in locpred[:,2]]


dispx = np.array(rel_loc_predx)
dispy = np.array(rel_loc_predy)
dispz = np.array(rel_loc_predz)
disp = np.sqrt(dispx**2+dispy**2+dispz**2)

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(ave_timestamps, disp, label='MLX')
plt.scatter(hdmm_time, hdmm_disp, label='HDMM')
#plt.scatter(hdmm_time[a:b], hdmm_disp2)
# Set x-axis labels to show only the time
# Format the x-axis to show date and time properly
plt.gcf().autofmt_xdate()  # Auto-format the dates on the x-axis
plt.ylim([-1, 6])
plt.xlabel('Index')
plt.ylabel('Total Displacement (mm)')
plt.title('Total Displacement')
plt.legend()
plt.grid(True)
plt.show()
